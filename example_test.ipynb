# %%
import sys
import argparse
import numpy as np
import cv2
import datetime
import time
import pytz
import json

from pipelines.document_structurization import DocumentStructurization
from modules.file_loading import load_document, load_whole_pdf

import pdfplumber
from pathlib import Path
import os
import logging
import pandas as pd
from langchain_core.documents import Document
from langchain_core.load.dump import dumps as lang_dumps

# %%
[t for t in pytz.all_timezones if t.startswith('America/Mex')]
# Out:
# ['America/Mexico_City']

# %%
def load_whole_pdf(pdf_path):

    # initialization
    image_list = []

    # read PDF file (load all pages in the PDF file)
    name = pdf_path.lower()
    if name.endswith('.pdf'):
        with pdfplumber.open(pdf_path) as pdf:
            page_count = len(pdf.pages)
            for page_index in range(page_count):  # traverse all pages
                page = pdf.pages[page_index]  # select the current page
                page_image = page.to_image(resolution=150) # convert the page to image by default (20230815)
                image = cv2.cvtColor(np.array(page_image.original), cv2.COLOR_RGB2BGR)

                image_list.append(image)

            pdf.close()

    return image_list

# %%
def whole_pdf_conversion_example(image_list):

    # configure
    configs = dict()
    
    layout_analysis_configs = dict()
    layout_analysis_configs['from_modelscope_flag'] = False
    layout_analysis_configs['model_path'] = '/home/DocXLayout_231012.pth'  # note that: currently the layout analysis model is NOT from modelscope
    configs['layout_analysis_configs'] = layout_analysis_configs
    
    text_detection_configs = dict()
    text_detection_configs['from_modelscope_flag'] = True
    text_detection_configs['model_path'] = 'damo/cv_resnet18_ocr-detection-line-level_damo'
    configs['text_detection_configs'] = text_detection_configs

    text_recognition_configs = dict()
    text_recognition_configs['from_modelscope_flag'] = True
    text_recognition_configs['model_path'] = 'damo/cv_convnextTiny_ocr-recognition-document_damo'  # alternatives: 'damo/cv_convnextTiny_ocr-recognition-scene_damo', 'damo/cv_convnextTiny_ocr-recognition-general_damo', 'damo/cv_convnextTiny_ocr-recognition-handwritten_damo' 
    configs['text_recognition_configs'] = text_recognition_configs

    formula_recognition_configs = dict()
    formula_recognition_configs['from_modelscope_flag'] = False
    formula_recognition_configs['image_resizer_path'] = '/home/LaTeX-OCR_image_resizer.onnx'
    formula_recognition_configs['encoder_path'] = '/home/LaTeX-OCR_encoder.onnx'
    formula_recognition_configs['decoder_path'] = '/home/LaTeX-OCR_decoder.onnx'
    formula_recognition_configs['tokenizer_json'] = '/home/LaTeX-OCR_tokenizer.json'
    configs['formula_recognition_configs'] = formula_recognition_configs

    # initialize
    document_structurizer = DocumentStructurization(configs)

    # run
    final_result = []
    page_index = 0
    for image in image_list:
        result = document_structurizer(image)

        page_info = {'page': page_index, 'information': result}
        final_result.append(page_info)

        page_index = page_index + 1

    if True:
        print (final_result)

    # release
    document_structurizer.release()

    return final_result

# %% [markdown]
# #### Manual tryout

# %%
#root_string = '/home/camilo/Documents/by_species/' #Conabio
root_string = '/home/camilo/Documents/00-Conabio/by_species/' #Casa
root_path = Path(root_string)

processed_list=['Leptonycteris yerbabuenae', 'Leptonycteris nivalis', 'Melipona beecheii'] 
species_subfolders = os.listdir(root_path)
pending_process_species = list(set(species_subfolders)-set(processed_list))
pending_process_species

# %%
import pdfplumber

my_full_path = '/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf' #casa
#my_full_path = '/home/camilo/Documents/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf' #Conabio
my_full_path
# Out:
# '/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'

# %%
df_agg = result_to_chunks(final_result)
# Out:
# information
# text_list

# %% [markdown]
# ### ALL TOGETHER NOW!

# %%
def check_species_processed(root_path, 
                            processed_list=['Leptonycteris yerbabuenae', 'Leptonycteris nivalis', 'Melipona beecheii']):
    species_subfolders = os.listdir(root_path)
    pending_process_species = list(set(species_subfolders)-set(processed_list))
    return pending_process_species

# %%
def get_list_paths(root_path, 
               input_subfolder_sufix="_bibliografía", 
               output_subfolder = "output"
               ):

    path_dics = []
    
    pending_process_species = check_species_processed(root_path)

    for species_folder in pending_process_species:
        species_folder_path = Path(root_path,species_folder)
        file_name_list = os.listdir(Path(root_path,species_folder,species_folder+'_bibliografía'))
        for file_name in file_name_list:
            path_dics.append(
                dict(
                    file_input_path = Path(species_folder_path,str(species_folder_path.name)+input_subfolder_sufix,file_name),
                    folder_output_path = Path(species_folder_path,output_subfolder),
                    species_folder = species_folder,
                    file_name = file_name
                )
            )
    return path_dics

# %%
root_path = '/home/camilo/Documents/by_species' #Conabio
root_path = '/home/camilo/Documents/00-Conabio/by_species' #casa

list_paths = get_list_paths(root_path)
list_paths[0].get('file_input_path')
# Out:
# PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf')

# %%
def loop_OCR(root_path, max_files = 100): 
    '''
    Expected folder Structure :

    root_folder/
        species A/
            species A_bibiliografía/
                file_A1.pdf
                file_A2.pdf
            output/
                Doc_A1
                Doc_A2
    
    Note: The subfolders under root_folde define the species-name. 
    '''
    list_paths = get_list_paths(root_path)
    final_results = []

    for file_path_dict in list_paths[0:max_files]:
        pdf_path = file_path_dict.get('file_input_path')
        output_folder = file_path_dict.get('folder_output_path')
        if not os.path.exists(output_folder):
            print("Creating output folder in : {output_folder.parent.name}")
            os.mkdir(output_folder)

        image_list = load_whole_pdf(str(pdf_path))

        try:
            final_result = whole_pdf_conversion_example(image_list)
            
            
        
        except:
            final_result = {'error_species':file_path_dict.get('species_folder'), 
                            'error_file': file_path_dict.get('file_input_path')
                            }
            logging.error("Custom_error_msg", exc_info=True)
        
        final_results.append(final_result)
    
    return final_results

# %%
def res_to_df_chunks(final_result: list, filter_criteria = ['plain text']) -> Document:
    # 1. Check if well defined
    # 1. to DataFrame and "Explode" for relevant columns
    # 2. Select type of objects, default 'plain text' category
    # 3. Group text into region-polygon-chunks

    # 1
    try: 
        df = pd.DataFrame(final_result)
        cols = ['information','text_list']

        for col in cols:
            print(col)
            df = df.explode(col).reset_index(drop=True)
            df = df.drop(columns=[col]).join(df[col].apply(pd.Series), rsuffix=f".{col}")

        df['content'] = df['content'].apply(lambda x: x[0] if isinstance(x,list) else '')
        df['region_poly'] = df['region_poly'].apply(lambda x: tuple(x)) # lists are mutable 
        df['content_type'] = df['content'].apply(lambda x: type(x).__name__)
        
        # 2
        df = df[df.category_name.apply(lambda x: x in filter_criteria)]

        # 3
        aggr_level = ['page', 'region_poly']
        grouped_df = df.groupby(aggr_level)
        # Concatenate the content of the 'content' column with spaces
        df_agg = df.groupby(aggr_level)['content'].apply(lambda x: ' '.join(x)).reset_index()
    
    except:
        return (final_result)

        
    return df_agg

# %%
list_paths[0].keys(), \
list_paths[0].get('folder_output_path').parent.name
# Out:
# (dict_keys(['file_input_path', 'folder_output_path', 'species_folder', 'file_name']),
#  'test species_A')

# %%
# warning
final_results = loop_OCR(root_path, max_files = 5)
# Out:
# Fix size testing.
# training chunk_sizes: [32]
# The output will be saved to  /home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../exp/ctdet_subfield/default
# heads {'hm': 11, 'cls': 4, 'ftype': 3, 'wh': 8, 'hm_sub': 2, 'wh_sub': 8, 'reg': 2, 'reg_sub': 2}
# Namespace(task='ctdet_subfield', dataset='huntie', test=False, data_src='default', exp_id='default', vis_corner=0, convert_onnx=0, onnx_path='auto', debug=0, load_model='/home/DocXLayout_231012.pth', resume=False, gpus=[0], num_workers=16, not_cuda_benchmark=False, seed=317, print_iter=0, hide_data_time=False, save_all=False, metric='loss', vis_thresh=0.3, nms_thresh=0.3, corner_thresh=0.3, debugger_theme='white', arch='dlav0subfield_34', head_conv=256, down_ratio=4, input_res=768, input_h=768, input_w=768, lr=0.000125, lr_step=[80], NotFixList='', num_epochs=90, batch_size=32, master_batch_size=32, num_iters=-1, val_intervals=5, trainval=False, negative=False, adamW=False, save_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../exp/ctdet_subfield/default', flip_test=False, test_scales=[1.0], nms=True, K=100, fix_res=True, keep_res=False, not_rand_crop=False, shift=0.1, scale=0.4, rotate=0, flip=0.5, maskvisual=0.0, maskgrid=0.0, no_color_aug=False, MK=500, rot=True, warp=True, normal_padding=True, extra_channel=False, init_emb='', grid_type='char_point', finetune_emb=False, dic='', sample_limit=-1, aug_rot=0, aug_ddd=0.5, rect_mask=False, kitti_split='3dop', mse_loss=False, num_classes=13, num_secondary_classes=3, reg_loss='l1', hm_weight=1, cls_weight=1, ftype_weight=1, mk_weight=1, off_weight=1, wh_weight=1, hp_weight=1, hm_hp_weight=1, dep_weight=1, dim_weight=1, rot_weight=1, peak_thresh=0.1, norm_wh=False, dense_wh=False, cat_spec_wh=False, not_reg_offset=False, agnostic_ex=False, scores_thresh=0.3, center_thresh=0.3, aggr_weight=0.0, dense_hp=False, not_hm_hp=False, not_reg_hp_offset=False, not_reg_bbox=False, eval_oracle_hm=False, eval_oracle_mk=False, eval_oracle_wh=False, eval_oracle_offset=False, eval_oracle_kps=False, eval_oracle_hmhp=False, eval_oracle_hp_offset=False, eval_oracle_dep=False, gpus_str='0', reg_offset=True, reg_bbox=True, hm_hp=True, reg_hp_offset=True, pad=0, num_stacks=1, chunk_sizes=[32], root_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../..', data_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../data', exp_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../exp/ctdet_subfield', debug_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../exp/ctdet_subfield/default/debug', mean=array([[[0.40789655, 0.44719303, 0.47026116]]], dtype=float32), std=array([[[0.2886383 , 0.27408165, 0.27809834]]], dtype=float32), output_h=192, output_w=192, output_res=192, heads={'hm': 11, 'cls': 4, 'ftype': 3, 'wh': 8, 'hm_sub': 2, 'wh_sub': 8, 'reg': 2, 'reg_sub': 2}, device=device(type='cpu'))
# --> loading model from local file: /home/DocXLayout_231012.pth
# 09/11/2024 16:58:48 - INFO - main -   Training parameters {'task': 'ctdet_subfield', 'arch': 'dlav0subfield_34', 'input_res': 768, 'num_classes': 13, 'load_model': '/home/DocXLayout_231012.pth', 'debug': 0}
# /home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/models/model.py:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=lambda storage, loc: storage)
# 2024-09-11 16:58:51,230 - modelscope - WARNING - Model revision not specified, use revision: v1.0.1
# 2024-09-11 16:58:52.675384: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-11 16:58:52.715764: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-11 16:58:53.511339: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-09-11 16:58:54,612 - modelscope - INFO - initiate model from /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo
# 2024-09-11 16:58:54,613 - modelscope - INFO - initiate model from location /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo.
# 2024-09-11 16:58:54,617 - modelscope - WARNING - No preprocessor field found in cfg.
# 2024-09-11 16:58:54,617 - modelscope - WARNING - No val key and type key found in preprocessor domain of configuration.json file.
# 2024-09-11 16:58:54,618 - modelscope - WARNING - Cannot find available config to build preprocessor at mode inference, current config: {'model_dir': '/home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo'}. trying to build by task and model information.
# 2024-09-11 16:58:54,618 - modelscope - WARNING - Find task: ocr-detection, model type: None. Insufficient information to build preprocessor, skip building preprocessor
# 2024-09-11 16:58:54,619 - modelscope - INFO - loading model from dir /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo
# 09/11/2024 16:58:54 - WARNING - tensorflow -   From /home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/env_doc/lib/python3.10/site-packages/modelscope/utils/device.py:60: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# /home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/env_doc/lib/python3.10/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# 09/11/2024 16:58:56 - WARNING - tensorflow -   From /home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/env_doc/lib/python3.10/site-packages/modelscope/pipelines/cv/ocr_utils/ops.py:744: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
# 2024-09-11 16:58:56,648 - modelscope - INFO - loading model from /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo/tf_ckpts/checkpoint-80000
# 09/11/2024 16:58:57 - INFO - tensorflow -   Restoring parameters from /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo/tf_ckpts/checkpoint-80000
# 2024-09-11 16:58:57.175007: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:353] MLIR V1 optimization pass is not enabled
# 2024-09-11 16:58:59,727 - modelscope - WARNING - Model revision not specified, use revision: v2.4.0
# 2024-09-11 16:59:00,345 - modelscope - INFO - initiate model from /home/camilo/.cache/modelscope/hub/damo/cv_convnextTiny_ocr-recognition-document_damo
# 2024-09-11 16:59:00,346 - modelscope - INFO - initiate model from location /home/camilo/.cache/modelscope/hub/damo/cv_convnextTiny_ocr-recognition-document_damo.
# 2024-09-11 16:59:00,347 - modelscope - INFO - initialize model from /home/camilo/.cache/modelscope/hub/damo/cv_convnextTiny_ocr-recognition-document_damo
# /home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/env_doc/lib/python3.10/site-packages/modelscope/models/cv/ocr_recognition/model.py:96: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   params_pretrained = torch.load(model_path, map_location='cpu')
# 2024-09-11 16:59:00,601 - modelscope - INFO - cuda is not available, using cpu instead.
# 2024-09-11 16:59:00,602 - modelscope - INFO - loading model from dir /home/camilo/.cache/modelscope/hub/damo/cv_convnextTiny_ocr-recognition-document_damo
# 2024-09-11 16:59:00,608 - modelscope - INFO - loading model done
# [{'page': 0, 'information': [{'category_index': 0, 'category_name': 'title', 'region_poly': [79, 194, 986, 194, 986, 265, 79, 265], 'text_list': [{'position': [81, 191, 986, 191, 986, 222, 81, 222], 'content': ['Spatial Segregation in Long-Nosed Bats, Leptonycteris nivalis and']}, {'position': [82, 230, 547, 231, 547, 261, 81, 261], 'content': ['Leptonycteris curasoae, in Mexico']}]}, {'category_index': 0, 'category_name': 'title', 'region_poly': [82, 466, 140, 466, 140, 481, 82, 481], 'text_list': [{'position': [82, 465, 137, 465, 137, 479, 82, 479], 'content': ['1 author:']}]}, {'category_index': 1, 'category_name': 'figure', 'region_poly': [92, 771, 128, 771, 128, 794, 92, 794], 'text_list': []}, {'category_index': 1, 'category_name': 'figure', 'region_poly': [92, 708, 129, 708, 129, 731, 92, 731], 'text_list': []}, {'category_index': 1, 'category_name': 'figure', 'region_poly': [82, 506, 124, 506, 124, 531, 82, 531], 'text_list': []}, {'category_index': 1, 'category_name': 'figure', 'region_poly': [142, 775, 319, 775, 319, 790, 142, 790], 'text_list': [{'position': [142, 774, 193, 774, 193, 788, 142, 787], 'content': ['Doctoral']}]}, {'category_index': 2, 'category_name': 'plain text', 'region_poly': [81, 657, 570, 657, 570, 672, 81, 672], 'text_list': [{'position': [81, 656, 568, 656, 568, 671, 81, 671], 'content': ['Some of the authors ofthis publication are also working on these related projects:']}]}, {'category_index': 2, 'category_name': 'plain text', 'region_poly': [120, 524, 383, 524, 383, 543, 120, 543], 'text_list': [{'position': [136, 525, 384, 523, 384, 538, 136, 539], 'content': ['Universidad Nacional Autonoma de Mexico']}]}, {'category_index': 2, 'category_name': 'plain text', 'region_poly': [132, 550, 316, 550, 316, 566, 133, 566], 'text_list': [{'position': [134, 550, 311, 549, 311, 563, 135, 564], 'content': ['89 PUBLICATIONS 3,591CITATIONS']}]}, {'category_index': 2, 'category_name': 'plain text', 'region_poly': [86, 302, 372, 302, 372, 322, 86, 322], 'text_list': [{'position': [81, 302, 221, 301, 221, 315, 81, 316], 'content': ['Article in Joumal of Ma']}, {'position': [238, 302, 303, 302, 303, 317, 238, 316], 'content': ['nalogy·No']}, {'position': [300, 302, 374, 302, 374, 316, 300, 316], 'content': ['vember 1991']}]}, {'category_index': 2, 'category_name': 'plain text', 'region_poly': [144, 584, 218, 584, 218, 600, 144, 600], 'text_list': [{'position': [150, 584, 212, 583, 212, 596, 151, 596], 'content': ['SEE PROFILE']}]}, {'category_index': 2, 'category_name': 'plain text', 'region_poly': [87, 325, 164, 325, 164, 337, 87, 337], 'text_list': []}, {'category_index': 2, 'category_name': 'plain text', 'region_poly': [136, 504, 223, 504, 223, 520, 136, 520], 'text_list': [{'position': [135, 503, 152, 503, 152, 515, 136, 515], 'content': ['He']}, {'position': [176, 503, 214, 503, 214, 516, 176, 516], 'content': ['TArita']}]}, {'category_index': 2, 'category_name': 'plain text', 'region_poly': [152, 714, 433, 714, 433, 729, 152, 729], 'text_list': [{'position': [141, 713, 393, 713, 393, 727, 141, 727], 'content': ['ecologia y conservacion de carnivoros View']}]}, {'category_index': 2, 'category_name': 'plain text', 'region_poly': [614, 389, 656, 389, 656, 424, 614, 424], 'text_list': [{'position': [622, 392, 650, 392, 650, 404, 622, 404], 'content': ['READS']}, {'position': [617, 411, 643, 411, 643, 425, 617, 425], 'content': ['386']}]}, {'category_index': 2, 'category_name': 'plain text', 'region_poly': [87, 403, 117, 403, 117, 429, 87, 429], 'text_list': [{'position': [81, 411, 97, 411, 97, 425, 81, 425], 'content': ['58']}, {'position': [105, 415, 105, 421, 90, 421, 90, 415], 'content': ['8']}]}, {'category_index': 3, 'category_name': 'header', 'region_poly': [1027, 71, 1177, 71, 1177, 91, 1027, 91], 'text_list': [{'position': [1026, 67, 1177, 68, 1177, 90, 1026, 90], 'content': ['ResearchGate']}]}, {'category_index': 3, 'category_name': 'header', 'region_poly': [82, 149, 694, 149, 694, 166, 82, 166], ' ...
# Fix size testing.
# training chunk_sizes: [32]
# The output will be saved to  /home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../exp/ctdet_subfield/default
# heads {'hm': 11, 'cls': 4, 'ftype': 3, 'wh': 8, 'hm_sub': 2, 'wh_sub': 8, 'reg': 2, 'reg_sub': 2}
# Namespace(task='ctdet_subfield', dataset='huntie', test=False, data_src='default', exp_id='default', vis_corner=0, convert_onnx=0, onnx_path='auto', debug=0, load_model='/home/DocXLayout_231012.pth', resume=False, gpus=[0], num_workers=16, not_cuda_benchmark=False, seed=317, print_iter=0, hide_data_time=False, save_all=False, metric='loss', vis_thresh=0.3, nms_thresh=0.3, corner_thresh=0.3, debugger_theme='white', arch='dlav0subfield_34', head_conv=256, down_ratio=4, input_res=768, input_h=768, input_w=768, lr=0.000125, lr_step=[80], NotFixList='', num_epochs=90, batch_size=32, master_batch_size=32, num_iters=-1, val_intervals=5, trainval=False, negative=False, adamW=False, save_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../exp/ctdet_subfield/default', flip_test=False, test_scales=[1.0], nms=True, K=100, fix_res=True, keep_res=False, not_rand_crop=False, shift=0.1, scale=0.4, rotate=0, flip=0.5, maskvisual=0.0, maskgrid=0.0, no_color_aug=False, MK=500, rot=True, warp=True, normal_padding=True, extra_channel=False, init_emb='', grid_type='char_point', finetune_emb=False, dic='', sample_limit=-1, aug_rot=0, aug_ddd=0.5, rect_mask=False, kitti_split='3dop', mse_loss=False, num_classes=13, num_secondary_classes=3, reg_loss='l1', hm_weight=1, cls_weight=1, ftype_weight=1, mk_weight=1, off_weight=1, wh_weight=1, hp_weight=1, hm_hp_weight=1, dep_weight=1, dim_weight=1, rot_weight=1, peak_thresh=0.1, norm_wh=False, dense_wh=False, cat_spec_wh=False, not_reg_offset=False, agnostic_ex=False, scores_thresh=0.3, center_thresh=0.3, aggr_weight=0.0, dense_hp=False, not_hm_hp=False, not_reg_hp_offset=False, not_reg_bbox=False, eval_oracle_hm=False, eval_oracle_mk=False, eval_oracle_wh=False, eval_oracle_offset=False, eval_oracle_kps=False, eval_oracle_hmhp=False, eval_oracle_hp_offset=False, eval_oracle_dep=False, gpus_str='0', reg_offset=True, reg_bbox=True, hm_hp=True, reg_hp_offset=True, pad=0, num_stacks=1, chunk_sizes=[32], root_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../..', data_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../data', exp_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../exp/ctdet_subfield', debug_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../exp/ctdet_subfield/default/debug', mean=array([[[0.40789655, 0.44719303, 0.47026116]]], dtype=float32), std=array([[[0.2886383 , 0.27408165, 0.27809834]]], dtype=float32), output_h=192, output_w=192, output_res=192, heads={'hm': 11, 'cls': 4, 'ftype': 3, 'wh': 8, 'hm_sub': 2, 'wh_sub': 8, 'reg': 2, 'reg_sub': 2}, device=device(type='cpu'))
# --> loading model from local file: /home/DocXLayout_231012.pth
# 09/11/2024 17:01:29 - INFO - main -   Training parameters {'task': 'ctdet_subfield', 'arch': 'dlav0subfield_34', 'input_res': 768, 'num_classes': 13, 'load_model': '/home/DocXLayout_231012.pth', 'debug': 0}
# /home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/models/model.py:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=lambda storage, loc: storage)
# 2024-09-11 17:01:32,611 - modelscope - WARNING - Model revision not specified, use revision: v1.0.1
# 2024-09-11 17:01:33,335 - modelscope - INFO - initiate model from /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo
# 2024-09-11 17:01:33,338 - modelscope - INFO - initiate model from location /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo.
# 2024-09-11 17:01:33,344 - modelscope - WARNING - No preprocessor field found in cfg.
# 2024-09-11 17:01:33,345 - modelscope - WARNING - No val key and type key found in preprocessor domain of configuration.json file.
# 2024-09-11 17:01:33,346 - modelscope - WARNING - Cannot find available config to build preprocessor at mode inference, current config: {'model_dir': '/home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo'}. trying to build by task and model information.
# 2024-09-11 17:01:33,348 - modelscope - WARNING - Find task: ocr-detection, model type: None. Insufficient information to build preprocessor, skip building preprocessor
# 2024-09-11 17:01:33,352 - modelscope - INFO - loading model from dir /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo
# /home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/env_doc/lib/python3.10/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# 2024-09-11 17:01:35,390 - modelscope - INFO - loading model from /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo/tf_ckpts/checkpoint-80000
# 09/11/2024 17:01:35 - INFO - tensorflow -   Restoring parameters from /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo/tf_ckpts/checkpoint-80000
# 2024-09-11 17:01:41,200 - modelscope - WARNING - Model revision not specified, use revision: v2.4.0
# 2024-09-11 17:01:42,545 - modelscope - INFO - initiate model from /home/camilo/.cache/modelscope/hub/damo/cv_convnextTiny_ocr-recognition-document_damo
# 2024-09-11 17:01:42,547 - modelscope - INFO - initiate model from location /home/camilo/.cache/modelscope/hub/damo/cv_convnextTiny_ocr-recognition-document_damo.
# 2024-09-11 17:01:42,554 - modelscope - INFO - initialize model from /home/camilo/.cache/modelscope/hub/damo/cv_convnextTiny_ocr-recognition-document_damo
# /home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/env_doc/lib/python3.10/site-packages/modelscope/models/cv/ocr_recognition/model.py:96: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   params_pretrained = torch.load(model_path, map_location='cpu')
# 2024-09-11 17:01:42,828 - modelscope - INFO - cuda is not available, using cpu instead.
# 2024-09-11 17:01:42,829 - modelscope - INFO - loading model from dir /home/camilo/.cache/modelscope/hub/damo/cv_convnextTiny_ocr-recognition-document_damo
# 2024-09-11 17:01:42,835 - modelscope - INFO - loading model done
# [{'page': 0, 'information': [{'category_index': 0, 'category_name': 'title', 'region_poly': [85, 986, 231, 986, 231, 1003, 85, 1003], 'text_list': [{'position': [83, 985, 230, 984, 230, 1001, 83, 1002], 'content': ['INTRODUCTION']}]}, {'category_index': 0, 'category_name': 'title', 'region_poly': [84, 190, 1112, 190, 1112, 258, 84, 258], 'text_list': [{'position': [82, 187, 1106, 191, 1106, 220, 82, 216], 'content': ['Pollination system of the Pilosocereus leucocephalus columnar']}, {'position': [83, 227, 738, 229, 738, 258, 83, 256], 'content': ['cactus (tribe Cereeae) in eastern Mexico']}]}, {'category_index': 0, 'category_name': 'title', 'region_poly': [83, 389, 159, 389, 159, 406, 83, 406], 'text_list': [{'position': [83, 389, 158, 389, 158, 404, 83, 404], 'content': ['Keywords']}]}, {'category_index': 0, 'category_name': 'title', 'region_poly': [418, 390, 513, 390, 513, 407, 418, 407], 'text_list': [{'position': [413, 390, 508, 390, 508, 406, 413, 406], 'content': ['ABSTRACT']}]}, {'category_index': 2, 'category_name': 'plain text', 'region_poly': [84, 1020, 590, 1020, 590, 1542, 84, 1542], 'text_list': [{'position': [81, 1020, 586, 1020, 586, 1038, 81, 1037], 'content': ['Columnar cacti are a group of New World tropical and']}, {'position': [81, 1042, 586, 1043, 585, 1063, 81, 1062], 'content': ['extratropical plants characterised by their cereoid habit. These']}, {'position': [83, 1067, 587, 1069, 587, 1085, 83, 1084], 'content': ['species are grouped into four tribes (Browningieae, Cereeae,']}, {'position': [82, 1088, 586, 1088, 586, 1106, 82, 1106], 'content': ['Pachycereeae and Trichocereeae) and all belong to the Cac-']}, {'position': [82, 1110, 583, 1112, 583, 1130, 82, 1129], 'content': ['toidae subfamily (Fleming & Valiente-Banuet 2002). The pol']}, {'position': [84, 1134, 587, 1135, 587, 1152, 84, 1152], 'content': ['lination system of columnar cacti - tribe Pachycereeae - has']}, {'position': [81, 1155, 586, 1156, 586, 1175, 81, 1174], 'content': ['been the focus of several studies (Valiente-Banuet 2002;']}, {'position': [83, 1180, 587, 1180, 587, 1197, 83, 1197], 'content': ['Valiente-Banuet et al. 2002). Most of the Mexican columnar']}, {'position': [81, 1202, 586, 1203, 586, 1222, 81, 1221], 'content': ['cacti belonging to this tribe (70%) bear typical bat-pollinated']}, {'position': [84, 1225, 587, 1227, 587, 1245, 83, 1243], 'content': ['flowers (Valiente-Banuet et al. 1996); however, a geographic']}, {'position': [82, 1247, 584, 1247, 584, 1265, 82, 1265], 'content': ['dichotomy in their pollination system has been identified.']}, {'position': [82, 1272, 584, 1269, 584, 1287, 82, 1289], 'content': ['Pollinator exclusion experiments revealed that chiropterophil']}, {'position': [81, 1295, 586, 1295, 586, 1311, 81, 1311], 'content': ['ous columnar cacti rely almost exclusively on bats to set fruit']}, {'position': [81, 1317, 585, 1317, 585, 1336, 81, 1335], 'content': ['in the tropical deserts of central Mexico (Valiente-Banuet et']}, {'position': [81, 1338, 585, 1339, 585, 1359, 81, 1358], 'content': ['al. 2002; Ibarra-Cerdena et al. 2005) and in Venezuela (Nas-']}, {'position': [82, 1365, 508, 1364, 508, 1381, 82, 1381], 'content': ['sar et al. 1997) - a specialised pollination systen']}, {'position': [519, 1365, 587, 1365, 587, 1380, 519, 1380], 'content': ['- while']}, {'position': [81, 1384, 586, 1384, 586, 1403, 81, 1402], 'content': ['both diurnal (bees and birds) and nocturnal visitors (bats)']}, {'position': [84, 1407, 587, 1408, 587, 1427, 84, 1426], 'content': ['effectively pollinate flowers and set fruit in the extratropical']}, {'position': [84, 1430, 588, 1433, 587, 1449, 84, 1447], 'content': ['deserts of North America - a generalised pollination system']}, {'position': [318, 1444, 318, 1463, 295, 1463, 295, 1444], 'content': ['.']}, {'position': [84, 1454, 587, 1453, 587, 1472, 84, 1473], 'content': ['(Fleming et al. 1996, 2001;Valiente-Banuet et al. 2004). Con-']}, {'position': [81, 1476, 5 ...
# Creating output folder in : {output_folder.parent.name}
# Fix size testing.
# training chunk_sizes: [32]
# The output will be saved to  /home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../exp/ctdet_subfield/default
# heads {'hm': 11, 'cls': 4, 'ftype': 3, 'wh': 8, 'hm_sub': 2, 'wh_sub': 8, 'reg': 2, 'reg_sub': 2}
# Namespace(task='ctdet_subfield', dataset='huntie', test=False, data_src='default', exp_id='default', vis_corner=0, convert_onnx=0, onnx_path='auto', debug=0, load_model='/home/DocXLayout_231012.pth', resume=False, gpus=[0], num_workers=16, not_cuda_benchmark=False, seed=317, print_iter=0, hide_data_time=False, save_all=False, metric='loss', vis_thresh=0.3, nms_thresh=0.3, corner_thresh=0.3, debugger_theme='white', arch='dlav0subfield_34', head_conv=256, down_ratio=4, input_res=768, input_h=768, input_w=768, lr=0.000125, lr_step=[80], NotFixList='', num_epochs=90, batch_size=32, master_batch_size=32, num_iters=-1, val_intervals=5, trainval=False, negative=False, adamW=False, save_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../exp/ctdet_subfield/default', flip_test=False, test_scales=[1.0], nms=True, K=100, fix_res=True, keep_res=False, not_rand_crop=False, shift=0.1, scale=0.4, rotate=0, flip=0.5, maskvisual=0.0, maskgrid=0.0, no_color_aug=False, MK=500, rot=True, warp=True, normal_padding=True, extra_channel=False, init_emb='', grid_type='char_point', finetune_emb=False, dic='', sample_limit=-1, aug_rot=0, aug_ddd=0.5, rect_mask=False, kitti_split='3dop', mse_loss=False, num_classes=13, num_secondary_classes=3, reg_loss='l1', hm_weight=1, cls_weight=1, ftype_weight=1, mk_weight=1, off_weight=1, wh_weight=1, hp_weight=1, hm_hp_weight=1, dep_weight=1, dim_weight=1, rot_weight=1, peak_thresh=0.1, norm_wh=False, dense_wh=False, cat_spec_wh=False, not_reg_offset=False, agnostic_ex=False, scores_thresh=0.3, center_thresh=0.3, aggr_weight=0.0, dense_hp=False, not_hm_hp=False, not_reg_hp_offset=False, not_reg_bbox=False, eval_oracle_hm=False, eval_oracle_mk=False, eval_oracle_wh=False, eval_oracle_offset=False, eval_oracle_kps=False, eval_oracle_hmhp=False, eval_oracle_hp_offset=False, eval_oracle_dep=False, gpus_str='0', reg_offset=True, reg_bbox=True, hm_hp=True, reg_hp_offset=True, pad=0, num_stacks=1, chunk_sizes=[32], root_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../..', data_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../data', exp_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../exp/ctdet_subfield', debug_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../exp/ctdet_subfield/default/debug', mean=array([[[0.40789655, 0.44719303, 0.47026116]]], dtype=float32), std=array([[[0.2886383 , 0.27408165, 0.27809834]]], dtype=float32), output_h=192, output_w=192, output_res=192, heads={'hm': 11, 'cls': 4, 'ftype': 3, 'wh': 8, 'hm_sub': 2, 'wh_sub': 8, 'reg': 2, 'reg_sub': 2}, device=device(type='cpu'))
# --> loading model from local file: /home/DocXLayout_231012.pth
# 09/11/2024 17:05:15 - INFO - main -   Training parameters {'task': 'ctdet_subfield', 'arch': 'dlav0subfield_34', 'input_res': 768, 'num_classes': 13, 'load_model': '/home/DocXLayout_231012.pth', 'debug': 0}
# 2024-09-11 17:05:19,572 - modelscope - WARNING - Model revision not specified, use revision: v1.0.1
# 2024-09-11 17:05:20,247 - modelscope - INFO - initiate model from /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo
# 2024-09-11 17:05:20,250 - modelscope - INFO - initiate model from location /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo.
# 2024-09-11 17:05:20,260 - modelscope - WARNING - No preprocessor field found in cfg.
# 2024-09-11 17:05:20,262 - modelscope - WARNING - No val key and type key found in preprocessor domain of configuration.json file.
# 2024-09-11 17:05:20,264 - modelscope - WARNING - Cannot find available config to build preprocessor at mode inference, current config: {'model_dir': '/home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo'}. trying to build by task and model information.
# 2024-09-11 17:05:20,266 - modelscope - WARNING - Find task: ocr-detection, model type: None. Insufficient information to build preprocessor, skip building preprocessor
# 2024-09-11 17:05:20,273 - modelscope - INFO - loading model from dir /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo
# 2024-09-11 17:05:22,319 - modelscope - INFO - loading model from /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo/tf_ckpts/checkpoint-80000
# 09/11/2024 17:05:22 - INFO - tensorflow -   Restoring parameters from /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo/tf_ckpts/checkpoint-80000
# 2024-09-11 17:05:25,162 - modelscope - WARNING - Model revision not specified, use revision: v2.4.0
# 2024-09-11 17:05:25,628 - modelscope - INFO - initiate model from /home/camilo/.cache/modelscope/hub/damo/cv_convnextTiny_ocr-recognition-document_damo
# 2024-09-11 17:05:25,631 - modelscope - INFO - initiate model from location /home/camilo/.cache/modelscope/hub/damo/cv_convnextTiny_ocr-recognition-document_damo.
# 2024-09-11 17:05:25,637 - modelscope - INFO - initialize model from /home/camilo/.cache/modelscope/hub/damo/cv_convnextTiny_ocr-recognition-document_damo
# 2024-09-11 17:05:25,871 - modelscope - INFO - cuda is not available, using cpu instead.
# 2024-09-11 17:05:25,871 - modelscope - INFO - loading model from dir /home/camilo/.cache/modelscope/hub/damo/cv_convnextTiny_ocr-recognition-document_damo
# 2024-09-11 17:05:25,876 - modelscope - INFO - loading model done
# [{'page': 0, 'information': [{'category_index': 0, 'category_name': 'title', 'region_poly': [191, 405, 1053, 405, 1053, 573, 191, 573], 'text_list': [{'position': [193, 403, 1044, 404, 1044, 459, 193, 459], 'content': ['PRODUCCION DEL ACHIOTE']}, {'position': [334, 508, 905, 509, 904, 571, 334, 570], 'content': ['(Bixa Orellana L.)"']}]}, {'category_index': 0, 'category_name': 'title', 'region_poly': [314, 276, 925, 276, 925, 338, 314, 338], 'text_list': [{'position': [328, 276, 926, 277, 926, 332, 327, 330], 'content': ['“MANUAL PARA LA']}]}, {'category_index': 1, 'category_name': 'figure', 'region_poly': [257, 701, 979, 701, 979, 1468, 257, 1468], 'text_list': []}]}, {'page': 1, 'information': [{'category_index': 0, 'category_name': 'title', 'region_poly': [286, 146, 952, 146, 952, 189, 286, 189], 'text_list': [{'position': [282, 145, 955, 145, 955, 187, 282, 186], 'content': ['UNIVERSIDAD VERACRUZANA']}]}, {'category_index': 0, 'category_name': 'title', 'region_poly': [222, 954, 1022, 954, 1022, 988, 222, 988], 'text_list': [{'position': [217, 951, 1018, 955, 1018, 986, 217, 983], 'content': ['PRESENTA: LEONARDO JAVIER NARCISO REYES']}]}, {'category_index': 0, 'category_name': 'title', 'region_poly': [315, 397, 929, 397, 929, 434, 315, 434], 'text_list': [{'position': [315, 395, 930, 398, 929, 431, 314, 428], 'content': ['FACULTAD DE CIENCIAS AGRICOLAS']}]}, {'category_index': 0, 'category_name': 'title', 'region_poly': [209, 634, 1034, 634, 1034, 673, 209, 673], 'text_list': [{'position': [209, 633, 1027, 636, 1027, 668, 209, 665], 'content': ['“MANUAL PARA LA PRODUCCION DEL ACHIOTE']}]}, {'category_index': 0, 'category_name': 'title', 'region_poly': [230, 642, 1016, 642, 1016, 751, 230, 751], 'text_list': [{'position': [209, 633, 1027, 636, 1027, 668, 209, 665], 'content': ['“MANUAL PARA LA PRODUCCION DEL ACHIOTE']}, {'position': [476, 713, 761, 715, 761, 749, 476, 748], 'content': ['(Bixa orellana)."']}]}, {'category_index': 2, 'category_name': 'plain text', 'region_poly': [483, 717, 760, 717, 760, 752, 483, 752], 'text_list': [{'position': [476, 713, 761, 715, 761, 749, 476, 748], 'content': ['(Bixa orellana)."']}]}, {'category_index': 2, 'category_name': 'plain text', 'region_poly': [261, 1275, 990, 1275, 990, 1382, 261, 1382], 'text_list': [{'position': [249, 1268, 987, 1271, 986, 1303, 249, 1301], 'content': ['PROFESOR DE EXPERIENCIA RECEPCIONAL:']}, {'position': [401, 1350, 848, 1351, 848, 1383, 401, 1381], 'content': ['ING. GABRIEL MAY MORA']}]}, {'category_index': 4, 'category_name': 'page number', 'region_poly': [615, 1631, 625, 1631, 625, 1649, 615, 1649], 'text_list': [{'position': [615, 1631, 623, 1631, 623, 1645, 615, 1645], 'content': ['1']}]}]}, {'page': 2, 'information': [{'category_index': 0, 'category_name': 'title', 'region_poly': [535, 141, 704, 141, 704, 167, 535, 167], 'text_list': [{'position': [533, 139, 702, 139, 702, 165, 533, 165], 'content': ['CONTENIDO']}]}, {'category_index': 2, 'category_name': 'plain text', 'region_poly': [218, 922, 960, 922, 960, 946, 218, 946], 'text_list': [{'position': [216, 917, 647, 921, 646, 946, 216, 942], 'content': ['9. Preparacion del terreno y riego ..']}, {'position': [931, 919, 961, 919, 962, 939, 931, 939], 'content': ['16']}]}, {'category_index': 2, 'category_name': 'plain text', 'region_poly': [252, 787, 961, 787, 961, 815, 252, 815], 'text_list': [{'position': [249, 783, 714, 784, 714, 811, 248, 809], 'content': ['8.1 Reproducción sexual por semilla ..']}, {'position': [917, 785, 961, 785, 961, 807, 917, 808], 'content': ['.14']}]}, {'category_index': 2, 'category_name': 'plain text', 'region_poly': [216, 1057, 966, 1057, 966, 1077, 216, 1077], 'text_list': [{'position': [216, 1049, 469, 1051, 469, 1075, 216, 1073], 'content': ['11.Ciclo del cultivo .']}, {'position': [917, 1051, 962, 1051, 962, 1072, 917, 1072], 'content': ['..19']}]}, {'category_index': 2, 'category_name': 'plain text', 'region_poly': [249, 852, 964, 852, 964, 877, 249, 877], 'text_list' ...
# Fix size testing.
# training chunk_sizes: [32]
# The output will be saved to  /home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../exp/ctdet_subfield/default
# heads {'hm': 11, 'cls': 4, 'ftype': 3, 'wh': 8, 'hm_sub': 2, 'wh_sub': 8, 'reg': 2, 'reg_sub': 2}
# Namespace(task='ctdet_subfield', dataset='huntie', test=False, data_src='default', exp_id='default', vis_corner=0, convert_onnx=0, onnx_path='auto', debug=0, load_model='/home/DocXLayout_231012.pth', resume=False, gpus=[0], num_workers=16, not_cuda_benchmark=False, seed=317, print_iter=0, hide_data_time=False, save_all=False, metric='loss', vis_thresh=0.3, nms_thresh=0.3, corner_thresh=0.3, debugger_theme='white', arch='dlav0subfield_34', head_conv=256, down_ratio=4, input_res=768, input_h=768, input_w=768, lr=0.000125, lr_step=[80], NotFixList='', num_epochs=90, batch_size=32, master_batch_size=32, num_iters=-1, val_intervals=5, trainval=False, negative=False, adamW=False, save_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../exp/ctdet_subfield/default', flip_test=False, test_scales=[1.0], nms=True, K=100, fix_res=True, keep_res=False, not_rand_crop=False, shift=0.1, scale=0.4, rotate=0, flip=0.5, maskvisual=0.0, maskgrid=0.0, no_color_aug=False, MK=500, rot=True, warp=True, normal_padding=True, extra_channel=False, init_emb='', grid_type='char_point', finetune_emb=False, dic='', sample_limit=-1, aug_rot=0, aug_ddd=0.5, rect_mask=False, kitti_split='3dop', mse_loss=False, num_classes=13, num_secondary_classes=3, reg_loss='l1', hm_weight=1, cls_weight=1, ftype_weight=1, mk_weight=1, off_weight=1, wh_weight=1, hp_weight=1, hm_hp_weight=1, dep_weight=1, dim_weight=1, rot_weight=1, peak_thresh=0.1, norm_wh=False, dense_wh=False, cat_spec_wh=False, not_reg_offset=False, agnostic_ex=False, scores_thresh=0.3, center_thresh=0.3, aggr_weight=0.0, dense_hp=False, not_hm_hp=False, not_reg_hp_offset=False, not_reg_bbox=False, eval_oracle_hm=False, eval_oracle_mk=False, eval_oracle_wh=False, eval_oracle_offset=False, eval_oracle_kps=False, eval_oracle_hmhp=False, eval_oracle_hp_offset=False, eval_oracle_dep=False, gpus_str='0', reg_offset=True, reg_bbox=True, hm_hp=True, reg_hp_offset=True, pad=0, num_stacks=1, chunk_sizes=[32], root_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../..', data_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../data', exp_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../exp/ctdet_subfield', debug_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../exp/ctdet_subfield/default/debug', mean=array([[[0.40789655, 0.44719303, 0.47026116]]], dtype=float32), std=array([[[0.2886383 , 0.27408165, 0.27809834]]], dtype=float32), output_h=192, output_w=192, output_res=192, heads={'hm': 11, 'cls': 4, 'ftype': 3, 'wh': 8, 'hm_sub': 2, 'wh_sub': 8, 'reg': 2, 'reg_sub': 2}, device=device(type='cpu'))
# --> loading model from local file: /home/DocXLayout_231012.pth
# 09/11/2024 17:11:16 - INFO - main -   Training parameters {'task': 'ctdet_subfield', 'arch': 'dlav0subfield_34', 'input_res': 768, 'num_classes': 13, 'load_model': '/home/DocXLayout_231012.pth', 'debug': 0}
# 2024-09-11 17:11:18,389 - modelscope - WARNING - Model revision not specified, use revision: v1.0.1
# 2024-09-11 17:11:19,778 - modelscope - INFO - initiate model from /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo
# 2024-09-11 17:11:19,780 - modelscope - INFO - initiate model from location /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo.
# 2024-09-11 17:11:19,790 - modelscope - WARNING - No preprocessor field found in cfg.
# 2024-09-11 17:11:19,792 - modelscope - WARNING - No val key and type key found in preprocessor domain of configuration.json file.
# 2024-09-11 17:11:19,794 - modelscope - WARNING - Cannot find available config to build preprocessor at mode inference, current config: {'model_dir': '/home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo'}. trying to build by task and model information.
# 2024-09-11 17:11:19,796 - modelscope - WARNING - Find task: ocr-detection, model type: None. Insufficient information to build preprocessor, skip building preprocessor
# 2024-09-11 17:11:19,801 - modelscope - INFO - loading model from dir /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo
# 2024-09-11 17:11:22,276 - modelscope - INFO - loading model from /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo/tf_ckpts/checkpoint-80000
# 09/11/2024 17:11:22 - INFO - tensorflow -   Restoring parameters from /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo/tf_ckpts/checkpoint-80000
# 2024-09-11 17:11:24,694 - modelscope - WARNING - Model revision not specified, use revision: v2.4.0
# 2024-09-11 17:11:25,401 - modelscope - INFO - initiate model from /home/camilo/.cache/modelscope/hub/damo/cv_convnextTiny_ocr-recognition-document_damo
# 2024-09-11 17:11:25,403 - modelscope - INFO - initiate model from location /home/camilo/.cache/modelscope/hub/damo/cv_convnextTiny_ocr-recognition-document_damo.
# 2024-09-11 17:11:25,409 - modelscope - INFO - initialize model from /home/camilo/.cache/modelscope/hub/damo/cv_convnextTiny_ocr-recognition-document_damo
# 2024-09-11 17:11:25,656 - modelscope - INFO - cuda is not available, using cpu instead.
# 2024-09-11 17:11:25,657 - modelscope - INFO - loading model from dir /home/camilo/.cache/modelscope/hub/damo/cv_convnextTiny_ocr-recognition-document_damo
# 2024-09-11 17:11:25,661 - modelscope - INFO - loading model done
# [{'page': 0, 'information': [{'category_index': 0, 'category_name': 'title', 'region_poly': [109, 1410, 230, 1410, 230, 1429, 109, 1429], 'text_list': [{'position': [108, 1410, 228, 1410, 228, 1426, 108, 1426], 'content': ['Introduction']}]}, {'category_index': 0, 'category_name': 'title', 'region_poly': [108, 261, 510, 261, 510, 284, 108, 284], 'text_list': [{'position': [107, 258, 509, 259, 509, 283, 107, 282], 'content': ['ORIGINAL RESEARCH ARTICLE']}]}, {'category_index': 0, 'category_name': 'title', 'region_poly': [100, 303, 989, 303, 989, 327, 100, 327], 'text_list': [{'position': [108, 299, 985, 302, 985, 327, 108, 325], 'content': ['Stingless bee distribution and richness in El Salvador (Apidae, Meliponinae)']}]}, {'category_index': 0, 'category_name': 'title', 'region_poly': [100, 272, 988, 272, 988, 327, 100, 327], 'text_list': [{'position': [108, 299, 985, 302, 985, 327, 108, 325], 'content': ['Stingless bee distribution and richness in El Salvador (Apidae, Meliponinae)']}]}, {'category_index': 2, 'category_name': 'plain text', 'region_poly': [152, 572, 1082, 572, 1082, 899, 152, 899], 'text_list': [{'position': [155, 566, 1079, 568, 1079, 586, 155, 584], 'content': ['This is the first complete inventory of stingless bees in El Salvador. It includes the spatial distribution of wild and man-']}, {'position': [155, 594, 1079, 588, 1079, 604, 155, 610], 'content': ['aged colonies and the relationships between their occurrence and vegetation cover, altitude and temperature. Applying']}, {'position': [157, 612, 1081, 609, 1081, 626, 157, 628], 'content': ['a stratified sampling, we located wild colonies (n =477) and managed colonies (n = 686) of stingless bees in tropical']}, {'position': [155, 632, 1079, 630, 1079, 646, 155, 648], 'content': ['forests, agricultural fields and urban areas. Each stratum (14) was a department (political division) of El Salvador. We']}, {'position': [157, 654, 1082, 650, 1082, 666, 157, 670], 'content': ['made maps of the distribution of the most common wild and managed species. We analysed spatial distribution of']}, {'position': [155, 674, 1079, 671, 1079, 687, 155, 690], 'content': ['colonies through the Clark and Evans Index (CEI). For the estimation of diversity between departments, the Shannon']}, {'position': [154, 694, 1079, 690, 1079, 707, 155, 710], 'content': ['Wiener diversity index (H) was calculated. The relationship between species richness and veetation cover was anal']}, {'position': [157, 718, 1081, 714, 1081, 730, 157, 734], 'content': ['ysed through the chi-square test. Linear regression was used to evaluate the effects of altitude and temperature on']}, {'position': [531, 723, 579, 723, 579, 742, 531, 743], 'content': ['son']}, {'position': [353, 726, 510, 726, 510, 746, 353, 747], 'content': ['cuded that: (al than']}, {'position': [157, 738, 1081, 733, 1081, 749, 157, 755], 'content': ['species richness. We condluded that: (a) there are at least 20 species, six subgenera and 10 genera of stineless bees in']}, {'position': [156, 755, 1078, 754, 1078, 770, 156, 771], 'content': ['El Salvador; (b) the departments with highest levels of diversity were Santa Ana (H=2.55), Chalatenango(H =2.41)']}, {'position': [155, 778, 1080, 772, 1080, 789, 155, 795], 'content': ['Morazan (H = 2.3I) and La Libertad (H =2.22); (c) the most abundant wild species. was Tetrggonisco oneustulo']}, {'position': [155, 800, 1078, 796, 1078, 812, 155, 816], 'content': ['(n = 156, relative abundance =32.70%) and was found in each department in clustered pattern (CEl =.26. b<.00I):']}, {'position': [428, 805, 428, 825, 408, 825, 408, 805], 'content': ['Y']}, {'position': [572, 808, 606, 808, 606, 828, 572, 828], 'content': ['9049']}, {'position': [156, 820, 1078, 817, 1078, 833, 156, 837], 'content': ['(d) Meipond beechei (n = 405, relative abundance = 59.04%) was the most frequent managed species, mainly found in a']}, {'position': [157, 841, 1081, 836, 1081, 852, 157, 856], 'content': ['Clustered p ...
# Fix size testing.
# training chunk_sizes: [32]
# The output will be saved to  /home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../exp/ctdet_subfield/default
# heads {'hm': 11, 'cls': 4, 'ftype': 3, 'wh': 8, 'hm_sub': 2, 'wh_sub': 8, 'reg': 2, 'reg_sub': 2}
# Namespace(task='ctdet_subfield', dataset='huntie', test=False, data_src='default', exp_id='default', vis_corner=0, convert_onnx=0, onnx_path='auto', debug=0, load_model='/home/DocXLayout_231012.pth', resume=False, gpus=[0], num_workers=16, not_cuda_benchmark=False, seed=317, print_iter=0, hide_data_time=False, save_all=False, metric='loss', vis_thresh=0.3, nms_thresh=0.3, corner_thresh=0.3, debugger_theme='white', arch='dlav0subfield_34', head_conv=256, down_ratio=4, input_res=768, input_h=768, input_w=768, lr=0.000125, lr_step=[80], NotFixList='', num_epochs=90, batch_size=32, master_batch_size=32, num_iters=-1, val_intervals=5, trainval=False, negative=False, adamW=False, save_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../exp/ctdet_subfield/default', flip_test=False, test_scales=[1.0], nms=True, K=100, fix_res=True, keep_res=False, not_rand_crop=False, shift=0.1, scale=0.4, rotate=0, flip=0.5, maskvisual=0.0, maskgrid=0.0, no_color_aug=False, MK=500, rot=True, warp=True, normal_padding=True, extra_channel=False, init_emb='', grid_type='char_point', finetune_emb=False, dic='', sample_limit=-1, aug_rot=0, aug_ddd=0.5, rect_mask=False, kitti_split='3dop', mse_loss=False, num_classes=13, num_secondary_classes=3, reg_loss='l1', hm_weight=1, cls_weight=1, ftype_weight=1, mk_weight=1, off_weight=1, wh_weight=1, hp_weight=1, hm_hp_weight=1, dep_weight=1, dim_weight=1, rot_weight=1, peak_thresh=0.1, norm_wh=False, dense_wh=False, cat_spec_wh=False, not_reg_offset=False, agnostic_ex=False, scores_thresh=0.3, center_thresh=0.3, aggr_weight=0.0, dense_hp=False, not_hm_hp=False, not_reg_hp_offset=False, not_reg_bbox=False, eval_oracle_hm=False, eval_oracle_mk=False, eval_oracle_wh=False, eval_oracle_offset=False, eval_oracle_kps=False, eval_oracle_hmhp=False, eval_oracle_hp_offset=False, eval_oracle_dep=False, gpus_str='0', reg_offset=True, reg_bbox=True, hm_hp=True, reg_hp_offset=True, pad=0, num_stacks=1, chunk_sizes=[32], root_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../..', data_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../data', exp_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../exp/ctdet_subfield', debug_dir='/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/../DocXLayout/../../exp/ctdet_subfield/default/debug', mean=array([[[0.40789655, 0.44719303, 0.47026116]]], dtype=float32), std=array([[[0.2886383 , 0.27408165, 0.27809834]]], dtype=float32), output_h=192, output_w=192, output_res=192, heads={'hm': 11, 'cls': 4, 'ftype': 3, 'wh': 8, 'hm_sub': 2, 'wh_sub': 8, 'reg': 2, 'reg_sub': 2}, device=device(type='cpu'))
# --> loading model from local file: /home/DocXLayout_231012.pth
# 09/11/2024 17:15:31 - INFO - main -   Training parameters {'task': 'ctdet_subfield', 'arch': 'dlav0subfield_34', 'input_res': 768, 'num_classes': 13, 'load_model': '/home/DocXLayout_231012.pth', 'debug': 0}
# 2024-09-11 17:15:34,342 - modelscope - WARNING - Model revision not specified, use revision: v1.0.1
# 2024-09-11 17:15:35,119 - modelscope - INFO - initiate model from /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo
# 2024-09-11 17:15:35,119 - modelscope - INFO - initiate model from location /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo.
# 2024-09-11 17:15:35,122 - modelscope - WARNING - No preprocessor field found in cfg.
# 2024-09-11 17:15:35,123 - modelscope - WARNING - No val key and type key found in preprocessor domain of configuration.json file.
# 2024-09-11 17:15:35,123 - modelscope - WARNING - Cannot find available config to build preprocessor at mode inference, current config: {'model_dir': '/home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo'}. trying to build by task and model information.
# 2024-09-11 17:15:35,124 - modelscope - WARNING - Find task: ocr-detection, model type: None. Insufficient information to build preprocessor, skip building preprocessor
# 2024-09-11 17:15:35,125 - modelscope - INFO - loading model from dir /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo
# 2024-09-11 17:15:37,308 - modelscope - INFO - loading model from /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo/tf_ckpts/checkpoint-80000
# 09/11/2024 17:15:37 - INFO - tensorflow -   Restoring parameters from /home/camilo/.cache/modelscope/hub/damo/cv_resnet18_ocr-detection-line-level_damo/tf_ckpts/checkpoint-80000
# 2024-09-11 17:15:40,692 - modelscope - WARNING - Model revision not specified, use revision: v2.4.0
# 2024-09-11 17:15:41,924 - modelscope - INFO - initiate model from /home/camilo/.cache/modelscope/hub/damo/cv_convnextTiny_ocr-recognition-document_damo
# 2024-09-11 17:15:41,927 - modelscope - INFO - initiate model from location /home/camilo/.cache/modelscope/hub/damo/cv_convnextTiny_ocr-recognition-document_damo.
# 2024-09-11 17:15:41,932 - modelscope - INFO - initialize model from /home/camilo/.cache/modelscope/hub/damo/cv_convnextTiny_ocr-recognition-document_damo
# 2024-09-11 17:15:42,274 - modelscope - INFO - cuda is not available, using cpu instead.
# 2024-09-11 17:15:42,275 - modelscope - INFO - loading model from dir /home/camilo/.cache/modelscope/hub/damo/cv_convnextTiny_ocr-recognition-document_damo
# 2024-09-11 17:15:42,281 - modelscope - INFO - loading model done
# 09/11/2024 17:16:00 - ERROR - root -   Custom_error_msg
# Traceback (most recent call last):
#   File "/tmp/ipykernel_78729/1208262450.py", line 29, in loop_OCR
#     final_result = whole_pdf_conversion_example(image_list)
#   File "/tmp/ipykernel_78729/2244096519.py", line 36, in whole_pdf_conversion_example
#     result = document_structurizer(image)
#   File "/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/pipelines/document_structurization.py", line 55, in __call__
#     det_result = self.text_detection_module(image)
#   File "/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/modules/text_detection.py", line 55, in __call__
#     det_result = self.text_detector(image)
#   File "/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/env_doc/lib/python3.10/site-packages/modelscope/pipelines/cv/ocr_detection_pipeline.py", line 194, in __call__
#     return super().__call__(input, **kwargs)
#   File "/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/env_doc/lib/python3.10/site-packages/modelscope/pipelines/base.py", line 220, in __call__
#     output = self._process_single(input, *args, **kwargs)
#   File "/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/env_doc/lib/python3.10/site-packages/modelscope/pipelines/base.py", line 259, in _process_single
#     out = self.postprocess(out, **postprocess_params)
#   File "/home/camilo/Documents/00-Conabio/01-Tutoriales/AdvancedLiterateMachinery/env_doc/lib/python3.10/site-packages/modelscope/pipelines/cv/ocr_detection_pipeline.py", line 242, in postprocess
#     raise Exception('modelscope error: No text detected')
# Exception: modelscope error: No text detected

# %%
final_results

# %%
list_paths[0:2]
# Out:
# [{'file_input_path': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'),
#   'folder_output_path': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/output'),
#   'species_folder': 'test species_A',
#   'file_name': 'Arita, 1991.pdf'},
#  {'file_input_path': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Munguia et.al., 2010.pdf'),
#   'folder_output_path': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/output'),
#   'species_folder': 'test species_A',
#   'file_name': 'Munguia et.al., 2010.pdf'}]

# %%
df_agg = res_to_df_chunks(final_results[0])
df_agg.head()
# Out:
# information
# text_list
#    page                               region_poly  \
# 0     0    (81, 657, 570, 657, 570, 672, 81, 672)
# 1     0    (86, 302, 372, 302, 372, 322, 86, 322)
# 2     0    (87, 325, 164, 325, 164, 337, 87, 337)
# 3     0    (87, 403, 117, 403, 117, 429, 87, 429)
# 4     0  (120, 524, 383, 524, 383, 543, 120, 543)
#
#                                              content
# 0  Some of the authors ofthis publication are als...
# 1      Article in Joumal of Ma nalogy·No vember 1991
# 2
# 3                                               58 8
# 4            Universidad Nacional Autonoma de Mexico

# %% [raw]
# ### pendiente implementación de esta lógina en loop_OCR
# if os.path.exists(arg3_output):
#             print(f"Skipping {arg3_output.name} - file already exists.")
#             break

# %%
file_path_dict = list_paths[0]
file_path_dict
# Out:
# {'file_input_path': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'),
#  'folder_output_path': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/output'),
#  'species_folder': 'test species_A',
#  'file_name': 'Arita, 1991.pdf'}

# %%
df_to_doc(df_agg, file_path_dict)
# Out:
# [Document(page_content='Some of the authors ofthis publication are also working on these related projects:'),
#  Document(page_content='Article in Joumal of Ma nalogy·No vember 1991'),
#  Document(page_content=''),
#  Document(page_content='58 8'),
#  Document(page_content='Universidad Nacional Autonoma de Mexico'),
#  Document(page_content='89 PUBLICATIONS 3,591CITATIONS'),
#  Document(page_content='He TArita'),
#  Document(page_content='SEE PROFILE'),
#  Document(page_content='ecologia y conservacion de carnivoros View'),
#  Document(page_content='READS 386'),
#  Document(page_content='Jones (1965) and Findley (1969) found segregation of certain sympatricspecies of vespertilionid bats along altitudinal gradients in Arizona aud New Mexico. Koopiman (1978) and Graliam (1983 I presented several examples of altitudinal segregation of closely related spccies of the Andes o Peru. Start and Marshall (1976) observed segregation by habitat in two species of Macroglossus tlhat occur sympatrically in Malaysia; M. mininus forages in coastal zones, feeding nainly or the flowers of Sonneratta sp., wbereas M. sobrinus selects lowers of wild banana plants (Musa sp.) that grow inland. Handley (1967) and Bonaccorso (1979) documented several examples of  segregation of sympatric bats by habital and vertical stratum in Ncotropical forests. Some othe examples of segregation of bat specics along gradients of altitude or habitat were discussed by IHumphrey and Bonaccorso (1979).'),
#  Document(page_content='Big (Leptonycteris nioalis) and little (L. curasoae) long-noscd bats are sympatric in central ... and northern Mexico (Arita and Humphrey, 1988). They are simiiar morpliologieally, and the differencc in size is slight; the body-mass ratio L. ntvalis:L. curasoae is L.42:1 (fron means ol 43 L. ntvalis and 13 L. curasoue males from Morelos and Distrito Federal). The existence of (wo speeics in North America was recognized when Davis and Carter (1962) reviewed the genus R The main food of both species is pollen and nectar of the flowers of some tropical and subtropica plants, especially cacti (Cactaceae) and certain species of Agave (Alvarez and Gouzalez-Q., 1970 Gardner, 1977; Quiroz et al., 1986). Baker and Coekrum (1966) suggested geographic and ecologic separation of these Iwo specles in North America, L. nicalis occurring priuarily in the highlands ot eastern Mexico and L. sanbornt (=L. curasoae) occupying lower elevatious in western and'),
#  Document(page_content='Based on the competitive-exclusion principle, two specics with identical or sitmilar ecological requirements cannot occur in the satne place at the same time. Wlen two closely related species are sympatric, soveral mcchanistus potentially can differentiate their niches and perinit their distributional ranges to overlap. One such ecological mechanisn is spatial segregation. Species can segregate within a given geographic area according to difflerences in habitat, vertical stratum, or altitude, or by presenting a checkerboard distribution in the case of archipelagoes (Diamond. 1975.1986)'),
#  Document(page_content='J. Mamm, 72(4):706-714.1991'),
#  Document(page_content='ABsTuACT.-Analysis of distributional pallerns of bats of tho genus Leptonueteris iu Mexico showed a spatial segregation of the Iwo species. Data on climate and vegetation were galhereo for 43 localities ol L. ntvalis and 269 of L. curasode reported in a recent taxonouic revision o the geus. A statistical analysis using a grid of quadrats of 1" of latitude and longitude showed no segregation of the two species at the ntacrogeographic seale. Ilowever, significant differences were found between the altitude and mean aumual temperature of lxcalities of the (wo species:  L. ntualts occurs in higher and cooler places than I. curasoae. No significant differences exist in terms of mean amuual precipitation; both species occur in drier zones of the couulty. I. nivalis oceurs more frequently in areas with pine (Pinus)-oak (Quercus) and tropical deciduous forests than expected by chance, whcreas L. curasoue is lound mainly in areas with tropieal deciduous and thorn forests. Bats of the genus Leptonycteris are the main pollinators of some suceies of maguey plants (Agave), and the ranges of the bats coincide with that of cettain species of Agave such as A. augustifolta (mezeal plant) A. salnian (pulque plant), and A. tequilang (tequil plant).'),
#  Document(page_content='University of Florida, Gainesoille, FL326I1 1'),
#  Document(page_content='Present address: Floridu Museunm of Nalural History.'),
#  Document(page_content='Universtty of Floridu. Gainesuiile, FL 32011'),
#  Document(page_content='HECTOR T. ARITA'),
#  Document(page_content='Arita, H.T. 1991. Spatial segregation in long-nosed bats, Leptonycteris nivalis and Leptonycteris curasoae, in Mexico. Journa of Mammalogy, 72:706-714.'),
#  Document(page_content='To test the hypotlhesis of geographic segregation of long-nosed lbats, Mexico was divided into 218 quadrats of one degree of latitude and lougitude. All localities of Leptonycteris in Mexico reported by Atita and llumphrey (1988) were located on a map and assigned to their respective quadrat. A two-by-lwo contingenev table analysis was enployed to test the null hypothesis that the distributions of l. ntoalts and L. curasoae in Mexico are independent'),
#  Document(page_content='species ol maguey plants (Agave). Bats of the genus Leptonycteris are known to be the primary pollinators of magueyes (Eguiarte and Burquez, 1987; Howell, 1979, Howell and Hartl, 1980: Howell and Botl, 1981; Martinez del Rio and Eguiarte, 1987). If a close association exists betweeo these plants and bats, matching distributional ranges are to be expected for both groups ol organisms. Furthermore, if spatial segregation occurs between the Iwo species of Leptonucters. ann association ol each species of lat with a partieular speeies of Agooe inight be predicted'),
#  Document(page_content="central Mexico. Since then, many localities have been added to the kuown distribution of Lep tonycteris in Mexico, allowing more rigorous analysis of Baker and Cockrun's (1966) idea. The objective of this paper is to use availablc informalion to test the hypothesis thiat spalial segregalion"),
#  Document(page_content='For each locality, I compiled metcorological data (ron Gareia (1981). These data included geographj coordinates, altitude, mcan annual precipitation, and mean annual temperature. Must of te stalions had records for both temperature and precipitation for ≥10 years of observations, but a lew lacked information tor one of these variables. ! first performed a Shapiro-Wilk test for uonmality to,analyze the frequeney distribution of altitude. temperalure., and precipitation of thc localities of botl species. All dlistributions were s significantly different from a nornal distribution (P <0.01), and I used only nonparametric tests in subsequent comparisons.'),
#  Document(page_content='Lotng-nosed bats are considered migratory specics (Alvarez and Gonzalez-(), 1970;Easterla, 1973;Hayward and Cookrum, 1971; Quiroz el al., I986), su sensonal novements in altitude or latitudle of one or buth species eouldl obscure dilferences between the specics. To analyze the extent of migration, I divided localities of each species into dry-season localities (records from Novemher to May) and wet-season localities (records froin June to October). Al(lhough this division could he considered arbitrary, It corresponds with the ap. proxitnale dation of the two main scasons in nmosi places in Mexico (Garcia, 1981). Wilcoxon (wo-sanple tests were perlorrned to compare for each species the localities of the two seasons int terms of altitude, mean atuual temperature, and moan annual precipitation. Subsequontly, I used additional Wilcoxon bwo-snmple tests comparing the localities of both species to test the hypothesis that differcnces in any of the three variables indicated spatial segregation of the two bat species'),
#  Document(page_content='Rcview of the literature pertaining to the listribution of te geus Leptonncteris las been hindered b monenclatural probleus. In a recent taxonotnic review of the genus, Arita and IIunphrey (1988) reported that many museutn spccimens labeled as L. nioalis were nisidentilied, and that tbis spocies has a moro restricted distribution than formerly bclieved. To avoid problems with crroneous distribulional records. I relicd only on localities reported by Arita and Humplrey (1988), who examined specimens ol L. ninalis froin 43 localities and of L. curasode from 269 localities (Fig. 1).'),
#  Document(page_content="I also compared the distributional range of the two bat species in terins of vegetation. I mapped localities of Leptonycteris on Rzedowski's (1978) vegetation map and tallied the number of localities of each species of bat in each of thc eight major types of vegetation: tropical rain forest; semi-evergreen tropical forest: tropical deciduous forest; thorn forest; grassland or savanna; desert or chapatral;pine (finus)-oak(Ouercus) Iorest; and cloud forest. I compared the frequency of oach bat species in each vegetation type with a pull distribution based on the proportion of Mexican territory covered by each of the eight types of vegetation e elg Deviation fron the null distribution woukd sugges! a nonrandon distribution of Leptonucterks species in terms of vegetation types, deuonstrating a seloction of some of tlie available environuents. I also used a binomial tost to compare the observed mumber of localities with the number of loealities expected to fail f a given type of vegetation if the distributions were randorn."),
#  Document(page_content='Distributional data presrnted by Gentry (1982) for Agace spccies were used to compare the distributions ol tlhese agaves in Mexico with distributions of both species of long-nosed bats, looking for a geoguaphic association supporting the hypothesis of an ecological relationship between the plants and one or both of the bat species. Special emphasis was given to three magueyes that are sources of traditional beverages in Mexico: Agave angustifolia, mezcal plant, A. salntlana, pulque plant, and A. tequilang. teqoila plant. I tested the'),
#  Document(page_content='hypothesis of an ossociation bctween L. curasoae and A. angustifolia by using a binonial distribution elassilying localities of bats as insilc or outsile the range of the agave. I made a qualitalive conparison of the distributions of L. ntorlis and A. sulnuiang, but no quantitalive test coull be performerl hecause of tho small sample.'),
#  Document(page_content='Of thc 218 1° quadrats that inelude Mexican territory, 24 include localities of L. ntvolis and 78 include L. curasoae. Sixtecn quadrats inciude localities of botb species. A. two-by-iwo con- tingency-table analysis demonstrated a significant positive association between the two species of bats on a macrogeographic seale (x’ = 11.2, d.f. = 1, P < 0.001, Fig. 1).'),
#  Document(page_content='For L. nivalis, I found no significant seasonal variation in altitude (Wilcoxon two-samplo test. P = (.56), mean annual temperature (P = 0.78), or mean annual precipitation(P=0.16). Similar results were obtained for L. curasoae (F = 0.17 for altitude, P= 0.41 for temperature, and P =0.32 precipitation). These results indicate that no seasonal pattern can be detected at the macrogcographic level. Because tno seasoual variation can be shown, I combined data for each species without regard to tiine of year.'),
#  Document(page_content='Most localities at which L. nioalis has been collected are between 1,000 and 2.200 in elevation (Fig. 2a), but L. nitalfs can reach highcr elevations; Saussure (1860) described the typo locality of this species at the snow line on the Pico de Orizaba, and Koestner (1941) reported a colony ol L. nipalis in the Cerro Fotosi, Nuevo Leon, at 3,780 m. In contrast,L. curdsoae, oceurs al lower elevations (Fig. 2a). Most locality records for this species are <1,800 n, and approximately one-third of them are <300 m. Unlike L. nivalis, L. curasoae frequently is caught at sea level. The altitude of the localities of L. nivalts is significantly higher than that of L. curasode (Wilcoxon lwo-sample test, P <0.001)'),
#  Document(page_content='Correlated with differences in altitude, a significant difference in mean annual temperalure exists between localities of the two species (Fig. 2b). The node of the frequency distribution of focalities of L. nivalis is 20C, whereas that for localities of L. curasoae is 25C. There is no significant difference in amnual rainfall between localities of the two species of loug-nosed bats (Fig. 2c). The frequency distributions of both specics are almost the same, with a tmode at about 750 mm.'),
#  Document(page_content='Localities of L. nivalis show a tonrandom distribution among tvpes of vegetation (x  = 100.1. md d.f. = 7, P < 0.001, Fig. 3). Only four of the cight types of vegetation are represented among known localities of L. nivalts. The big long-nosed bat is positively associated with tropical deciduous and pine-oak forests (binomial tests, P <0.01 and P < 0.001, respectively), and negatively associated with grassland (P < 0.01) and tropica! rain forests (P <0.05). Similarly. the distribution of L. curasode among types of vegetation is not random (x’ = 624.7, d.f. = 7. P < 0.001, Fig. 3). The little long-nosed bat occurs more frequently in dry forests (tropical deciduous, thorn, and semi-evergreen) than expected by chance (P < 0.001) and is negatively associated with deserts, grasslands, and tropical rain forests (P < 0.001)'),
#  Document(page_content='The distribution of L. cutdsoae in Mexico coincides with the range of the mezcal plant. A in ocalities   ant  Ih Th   curasoae ie ran concentrated mainly on the Baja California peninsula and in northeastern Mexico. Also, some populations ol A. angustifolia occur in the northern part of the Yucatan peninsula where the little long-nosed bat does not occur. A. angustifolta is mainly a form of the Moxican tropical lowlands, occurring chielly in tropical savannas, thorn forests, and tropical deciduous forests, in plo areas with anmual precipitation from 250 to 1,680 mm. Distributional records are from sea level to ca. 1,500 m (Centry, 1982). The tequila plant (A. tequilano) is closely related to A. angustifolta and nay only be a variety of the mczcal plant (Centry, 1982). This plant grows wild in the vicinity ol Tequila, Jalisco, where the little long-nosed bat has becn collected (Arita and Hum plrev, 1988).'),
#  Document(page_content='The pulque plant (A. salmtana) and other species of the Salmianae group, as arranged by'),
#  Document(page_content='Gentry (1982), grow in habitats where I. nionlis is abudant. These plants are native to the lighlands of the Transverse Volcanic Belt aud are found at elevations between 1.250 aud 2.500 m, where annual rainfall ranges from 350 to 1,000 mm (Gentry, 1982).'),
#  Document(page_content='Long-nosed bats are not geographically segregated. A[ter Davis and Carter (1962) demo- strated the prescnce of two spccies of Leptonycteris in North America, it was believed that they were syimpatric only in central Mexico. Most locality records reported by Baker and Coekrun (1966), Ramirez-P. and Alvarez (1972), and IHall (1981) showed that L. ntoalis was fouud mainly in northeastern Mexico, whereas L. curasode occurred chiefly in western and southern Mexico. However, the revision by Arita and IIumphrey (1988) demonstrated thal L. curasoue is more widespread in northeastern Mexico than formerly bclieved (Wilson el al., 1985). and that the idea of a geographic segregation between long-nosed bats was cuused by misidentification of many specimens of L. curasoae as L. nipalis. In rcality, the distributional range of L. nitalis i almost completely included in the range of I. curasoae. The only placus outside the rangc of L. curasoae where L. ntvalis is known to oceur are the Big Bend National Park arca iu Texas'),
#  Document(page_content='(Easterla, 1973) and sotne tparts of Coaloila (Easterla, 1972; Wilson et al., 1985). My analysis contirins a positive association bctween the two Leptonycteris species at the macrogeographio scale'),
#  Document(page_content='As suggested by Baker and Cockrum (1966), long-nosed bats segregate in an altitudinal gradient, with L. nioalts oecurring at higher and cooler localities than L. curasoue (Fig. 2). Both species are found more frequently in dry areas of the country, with annual rainfall <2,000 mn. Mexico generally is a dry country, althougl it includes regions with anmual precipitation of >4,000 mtn. Long-nosed bats do not occur in those parts of the country (Fig. 2), suggesting that bats of the genus Leptonycteris are adapted to arid conditions, as diseussed by Koopman (1981). The two species of long-nosed bat occur at localities with different types of vegetation (IFig. 3). As obscrved by Baker and Cockrum (1966), the nost comnon habitat for L. nivalis is the transition zone between tropieal deciduous forest and pine-oak forest. Couversely. L.curasoae is more frequently found in places characterized by tropical aud subtropical dry forests.'),
#  Document(page_content='The mezcal plant and L. curasoae occur in almost identical areas; uany of the localities of A. angustifolia listed by Gentry (1982) are close to collection sitos of the little long-nosed bat. This geographic association, and the close plant-pollinator relatiouship demonstrated belween L. curasoae and other species of Agavaceae (Eguiarte and Burquez, 1987; Howell, 1979; Howel and fHartl, 1980, Ilowell and Roth, 1981) might suggest that L. curdsoae coukl be a pollinator of wild mezcal plants. However, the possibility exists that the posilive gcographic association .. demonstrated herein may be only a consequence of both the bat and the agave occurring cbielly in arid parts of the country; only direct field observations could confirm an ecological association between these species. A. salmiana is a bat-pollinated plant (Martinez del Rio and Eguiarte 1987), but thc identity of tho species that pollinates this maguey remains unknown. On the basis of the habitats in which the plant grows, that pollinator could be L. nioalis, but this must be confirmed by field studies.'),
#  Document(page_content='The two species of long-nosed bats seern to have similar fceding lhabits and fotaging strategies Alvarez and Gonzalez-(). (1970) fouud that both specics of Leptonycteris depend beavily on plauts of the genera Agave, Myrtillocactus, Cetba, Ipomoea, and Bombux, and that the only dietary difference between the two species was the relative proportion of pollen of these plant in their diet. Given the altitudinal segregation of long-osed bats, it is possible that even if the lwo species of Leptonycteris feed on nectar and pollen of the same genera of plants, as dem onstrated by Alvarez and Gonzalez-Q. (1970), they could specialize on different species; it seems that L. curasode exploits lowland species of magueyes and L. nipalis leods on highland species'),
#  Document(page_content='Diamond (1986) found spatial segregation to be the most froquent mechanism allowing pairs of bird species to cxist sympatrically in New Guinea; among sucl pairs of species, be found little evidence of ecological segregation in feeding habits or body mass. Diamond (1986) found that pairs of bird species in New Guinea willi body-mass ratios <1.7:l are never truly syntopic, unless they have different diets or foraging behavior. Morplological and dietary similarities between the two species of Leptumycteris suggest that altitudinal segregation is the mechanisn that allows them to be sympatric. This segrcgation, liowever, is incomplete; there is overlap in altitudes occupied by the two species (Fig. 2), and there are several reports of both species being caught in the same place at the same timc (Villa-R., 1967; Wilson et al., 1985). Currently, no information is available to suggest an ecological mechanism that could explain these cascs of syntopic oc currence of long-nosed bats'),
#  Document(page_content='La existencia de una segregacion espacial entre las dos especics de murcielagos magueyeros (genero Leptonycteris) puede ser denostrada mediante el analisis de los patrones de distribucion de estos auimales. Se obtuvieron datos sobre el clina y la vegetacion de 43 localidades de L. nivalts y 269 de L. curasoae en Mexico usatdo como base los registros de una revision taxonomica del genero recientemente publicada. El analisis estadistico de la distribucion de las especies utilizando cuadrantes de un grado por lado no pudo denostrar una scgregacion de las especies'),
#  Document(page_content='November 1991'),
#  Document(page_content='BAKER, R. I, AND E. L. COCKRUM. 1966. Geograph ical and ecological range of the long-nosed bats. Leptonycteris. journal of Mamnalogy, 47:329- 331'),
#  Document(page_content='I thank S. R. Ilunphrey for continuous suppott of my research on long-osed bats. C. Martinez del Rio D. E. Wilson, and an anonynous reviewer provided good ideas aud stimulhting criticisnt. This rcseareh was made possible by scholarships fron the Cousejo Nacional de Ciencia y Tocnologia and the Universidad Nacional de Mexico. This is a contribution of the Progran for Studies iu Tropieal Conservation and a contribution of the Journal Series, Florida Agricultural Exueriueut Station. Gainesville Florid'),
#  Document(page_content='crop cu. cias alya..se enconimfon dnetenctas aguneateu eratura media oeci L.1 zonas mas allas y frias que L. curasode. No se encontraron diferencias entre la precipitacion media atual de las localidades de las dos especies; ambas oxeupan lus partes mas secas del pais. a L. nivalis se encuentra en areas con bosque de encino y coniferas o con bosque tropical cadueifolic con nayor frecuencia que la esperadla al azar, mientras que L. curasode se encuentra princi- palmente en los bosques tropical caducifolio y cspinoso. Los inurcielagos del genero L.eptonycteris son los ptincipales polinizadores de algunos nagueyes (genero Agave), v sus patrones de distri- bucion coincilen con lus de algunas especies de magueyes de importaneia comercial, cono el maguey mezcalero (A. angustifolta), el maguey pulquero (A. salmiana) y el maguey tequilerc (A. tequilana)'),
#  Document(page_content='ARITA, IH. T., AND S.R.HUMPHREY. 1988. Revision taxonomica de los mureielagos inagueyeros del ge nero Leptongcterts (Chiroplera: Phyllostomidae). Aeta Zoologica Mexicana, nueva serie. 29:1-60.'),
#  Document(page_content='ALVAREZ, T., AND L. GONZALEZ-(). 1970. Analisis polinico del contenido gastrico de murcielagos Glossophaginae de Mexico. Anales de la Eseuela Nacional de Ciencias Biologicas (Mexico), 18:137- 165.'),
#  Document(page_content='DIAMOND, J. M. 1975. Assenmbly of species con- munities. Pp. 342-444, tn Ecology and evolution of cominunities (M. L. Cody and I. M. Diamond. eds.). Belknap Press, Cambridge, Massachuselts. 545 pp.'),
#  Document(page_content='BONACCORSO, F.J. 1979. Foraging and reprodue tive ecology in a Panaanian bat cominunily. Bul letin of the Florida State Museum, Biological Sei- ences, 24:350-408 y'),
#  Document(page_content='1986. Evolution aund ecological segregation in the New Guinca montane avifauna.Pp98-125. in Community ecology (J. M. Diamond and T. I. Case, eds.) llarper and Row, New York. 665 pp.'),
#  Document(page_content='Case, eds.) llarper and Row, New York. 665 pp. EASTERLA, D. A. 1972. Status of Leplonucteris nt valis(Phyllostomatidea) in Big Bend National Park, Texas. The Southwestern Naturalist. 17:287-292 1973. Ecology of the 18 species of Chi roplera at Big Bend National Park, Texas. Part Jl'),
#  Document(page_content='DAVIs, W. B., AND D. C. CARTEH. 1962. Review of the genus Leptonucterts (Mamnalia: Chiroptera) Iroceedings of the Biological Soeiely of Washiug. 10 ton, 75:193-198'),
#  Document(page_content='EGUIARTE, L., ANDA.BURQUEZ. 1987. Reproductive ecology of Manfreda brachystochua, an iteropa'),
#  Document(page_content='FINDLEY.J.S. 1969. Biogeograply of southwesteri boreal and desert imamals. Pp. 113-128,in Con tributions in manalogy (J. K. lones、 lr., ed.) Miscellaneous Publicalious, Museun of Natura History, University of Kausas, 51:1-428'),
#  Document(page_content='GARCiA,E 1981. Modificacioues al sistea de clasi fieacion elimatica de Koppen (pata adaptarlo a las condiciones de la Republica Mexicana). Third ed Larios, Mexieo Cily, 252 pp.'),
#  Document(page_content='GARONER.A.L. 1977. Feeding habits. Po.293-350 an.. ,yfhyl atd D. C. Carter, eds.). Special Pullieatious, The'),
#  Document(page_content='IloWELL, D. J., AND B. S. ROTH. 1981. Sexual re'),
#  Document(page_content='HANDLEY, C. O., JR. 1967. Bals of the canopy of an Amazotian forest. Atlas Simposio Biota Ama zonica,5:211-215.'),
#  Document(page_content="GENTRY, I1.S. 1982. Agaves of contineutal North America. Univetsily of Arizona I'ress, Tueson, 670 pp."),
#  Document(page_content='lloWELL, ). J, AND D. L. HARTI. 1980. Optitna loraging in glossophagine bats: when to give up. The Ainerican Naluralist. 115:696-704.'),
#  Document(page_content='GAA11AM, G. I 1983. Changes in bat species di versity along an elevational gradient up the Pe ruvian Andes. Journal of Maminalogy. 64:559-571.'),
#  Document(page_content='HOWELL, D. J. 1979. Flock foraging in tectar-eal iug bats: advantages to the bals and to the host plant. The American Naturalist, 114:23-49'),
#  Document(page_content='IIALL,E.R. 1981. The mamumals of North America Second ed. Joln Wiley and Sons. New York. |:1- G00+90'),
#  Document(page_content='HAYWARD. B. J, AND E. L. CoCKRtM. 1971. The nalural history of the western loug-nosed bat Lep tonycteris sanborni. Weslern New Mexico Uni versity Research in Science, 1:75-123.'),
#  Document(page_content='rous species of Agavaccae. Tle Southwestern Nat- uralist, 32:169--178'),
#  Document(page_content='JONES,C. 1965. Eeologicaldistributionsand activity periods of bats of the Mogollon Mounitains area o New Mexieo and adjacent Arizona. Tulane Studie! in Zoology, 12:93-100.'),
#  Document(page_content='Population and comununity eeology. Pp.409-441. tn Biology of bats of the New World family Phvl- lostomalidae. Pait 111 (R. J. Baker, J. K. Jones, Jr., and D. C. Carter, eds.). Spectal Publieations, The Museum, Texas Teeh University, 16:1-441.'),
#  Document(page_content='KOESTNER, E. I. 1941. An annotaled list of main tmals eollected in Nuevo Lcon, Mexico, in 1938 as The Great Basin Naturalist. 2:9-15.'),
#  Document(page_content='KOOTMAN, K. F. 1978.Zoogeography of Peruvian bats with special emphasis on the role of the Andes. Ainerican Museum Novitales, 2651:1-83'),
#  Document(page_content='MARTINEZ DEL Rio, C., AND L. F. EGUIANTE 1987 Bird visitatiou lo Agave salmiana: conparisons anong hummingbirds and perching birds. The Condor, 89:357-363.'),
#  Document(page_content='Quntoz, D. L., M. S. XELIIUANTZI,AND M. C. ZAMORA. 1986. Analisis palinologico del coutenido gastro'),
#  Document(page_content='1981. The distributional patterns of New World nectar-feeding bats. Annals of the Missouri Botanical Garden, 68:352-369.'),
#  Document(page_content='production in agaves: the benefits of bats; the cost of semelparous advertising. Ecology, 62:1-7 7'),
#  Document(page_content='Submitted 20 October 1968. Accepted 3 Lecember 1990.'),
#  Document(page_content='RZEDOW5KI, J. 1978. Vegetacion de Mexico. Li musa, Mexico City, 432 pp.'),
#  Document(page_content='los imurcielagos del genero Leptonycteris en Mexi eo, con la desiguaciou del lectolipo de L. gerba- buenae Martinez y Villa, 1940. The Southwestern Naturalist, 16:249-259'),
#  Document(page_content='SAUSSURE,M. 1860. Note sur quelques mammiferes du Mexique. Revile et Magazinede Zoologie,Iaris, series 2, 12:281-293.'),
#  Document(page_content='START, A. N., AND A. G. MARSHALL. 1976. Neclar- ivorous bats as pollinators of trees in West Malay- sia. Pp 141-150, in Tropical trees. Variation, breeding and conscrvation (l. Burlev and B. T. Styles, eds.). Academic Press, London, 243 pp'),
#  Document(page_content='WILSON, D. E., R. A. MEDELLIN, D. V. LANNING, AND 1H.T. ARITA. 1985. Los murcielagos del ioreste de Mexico. con utia lista de especies. Acta Zoolo gica Mexicaina, nueva serie, 8:1-26'),
#  Document(page_content='VHLA-R., B. 1967. Los mureielagos de Mexico. In- e slituto de Biologia, Universidad Nacional Aulono- ma de Mexico, 491 pp.'),
#  Document(page_content='intestinal de los murcielagos Clossophaga soricina y Leptonycteris verbabuenae de las grutas de jux tlahuaca, Guerrero. Instituto Nacional de Autro pologia e lIistoria, Mexico City, 51 pp.')]

# %%
len(final_results)
# Out:
# 5

# %%
def df_to_doc(df_agg, file_path_dict):
    """Converts a Pandas DataFrame to a list of LangChain Documents with enhanced data handling.

    Args:
        df_agg (pandas.DataFrame): The DataFrame containing the data to be converted.
        file_path_dict (dict): A dictionary containing file paths for various purposes.

    Returns:
        list: A list of LangChain Document objects with page_content and metadata.
    """

    documents = []
    for _, row in df_agg.iterrows():
        metadata = {
            "page": row.get("page"),  # Use get() for potential missing values
            "file_name": file_path_dict.get("file_name"),
            "region_poly": row.get("region_poly"),
            "input_file": file_path_dict.get("file_input_path"),
            "species_folder": file_path_dict.get("species_folder"),
            "output_folder": str(Path(file_path_dict.get("folder_output_path"))),  # Convert Path to string for JSON
            "output_file": str(Path(file_path_dict.get("folder_output_path"), file_path_dict.get("file_name").split(".")[0] + ".json"))  # Use get() and string conversion
        }

        # Remove potential None values from metadata
        metadata = {key: value for key, value in metadata.items() if value is not None}

        documents.append(Document(page_content=row.get("content"), metadata=metadata))

    return documents

# %%
def df_to_doc(df_agg, file_path_dict):
    """Converts a Pandas DataFrame to a list of LangChain Documents with enhanced data handling.

    Args:
        df_agg (pandas.DataFrame): The DataFrame containing the data to be converted.
        file_path_dict (dict): A dictionary containing file paths for various purposes.

    Returns:
        list: A list of LangChain Document objects with page_content and metadata.
    """

    documents = [
        Document(
            page_content=row.get("content"),
            metadata={
                "page": row.get("page"),  # Use get() for potential missing values
                "file_name": file_path_dict.get("file_name"),
                "region_poly": row.get("region_poly"),
                "input_file": file_path_dict.get("file_input_path"),
                "species_folder": file_path_dict.get("species_folder"),
                "output_folder": str(Path(file_path_dict.get("folder_output_path"))),  # Convert Path to string for JSON
                "output_file": str(Path(file_path_dict.get("folder_output_path"), file_path_dict.get("file_name").split(".")[0] + ".json"))  # Use get() and string conversion
            }
        )
        for _, row in df_agg.iterrows()
    ]

    return documents

# %%
file_path_dict.get("folder_output_path")
# Out:
# PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/output')

# %%
len(df_to_doc(res, path_dic))
# Out:
# 84

# %%
dfs = [res_to_df_chunks(df) for df in final_results]


for res, path_dic in  zip(dfs,list_paths):
    output_file_path = Path(path_dic.get('folder_output_path'),
                            path_dic.get('file_name').split(".")[0]+".json")
        
    # if it is a DataFrame, result finished correctly
    if isinstance(res, pd.DataFrame):
         list_of_docs = df_to_doc(res, path_dic)
         lang_dumps(list_of_docs, pretty=True)
    else:
         lang_dumps(res, indent = 4)
# Out:
# information
# text_list
# information
# text_list
# information
# text_list
# information
# text_list

# %%
list_paths
# Out:
# [{'file_input_path': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'),
#   'folder_output_path': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/output'),
#   'species_folder': 'test species_A',
#   'file_name': 'Arita, 1991.pdf'},
#  {'file_input_path': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Munguia et.al., 2010.pdf'),
#   'folder_output_path': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/output'),
#   'species_folder': 'test species_A',
#   'file_name': 'Munguia et.al., 2010.pdf'},
#  {'file_input_path': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_B/test species_B_bibliografía/Narciso-Reyes, 2003.pdf'),
#   'folder_output_path': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_B/output'),
#   'species_folder': 'test species_B',
#   'file_name': 'Narciso-Reyes, 2003.pdf'},
#  {'file_input_path': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_B/test species_B_bibliografía/Ruano-Iraheta et al., 2015.pdf'),
#   'folder_output_path': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_B/output'),
#   'species_folder': 'test species_B',
#   'file_name': 'Ruano-Iraheta et al., 2015.pdf'},
#  {'file_input_path': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_B/test species_B_bibliografía/Pat-Fernández et al., 2018.pdf'),
#   'folder_output_path': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_B/output'),
#   'species_folder': 'test species_B',
#   'file_name': 'Pat-Fernández et al., 2018.pdf'}]

# %%
doc = df_to_doc(res, path_dic)

# %%
with open(path_)doc
# Out:
# [Document(metadata={'page': 0, 'file_name': 'Arita, 1991.pdf', 'region_poly': (81, 657, 570, 657, 570, 672, 81, 672), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='Some of the authors ofthis publication are also working on these related projects:'),
#  Document(metadata={'page': 0, 'file_name': 'Arita, 1991.pdf', 'region_poly': (86, 302, 372, 302, 372, 322, 86, 322), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='Article in Joumal of Ma nalogy·No vember 1991'),
#  Document(metadata={'page': 0, 'file_name': 'Arita, 1991.pdf', 'region_poly': (87, 325, 164, 325, 164, 337, 87, 337), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content=''),
#  Document(metadata={'page': 0, 'file_name': 'Arita, 1991.pdf', 'region_poly': (87, 403, 117, 403, 117, 429, 87, 429), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='58 8'),
#  Document(metadata={'page': 0, 'file_name': 'Arita, 1991.pdf', 'region_poly': (120, 524, 383, 524, 383, 543, 120, 543), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='Universidad Nacional Autonoma de Mexico'),
#  Document(metadata={'page': 0, 'file_name': 'Arita, 1991.pdf', 'region_poly': (132, 550, 316, 550, 316, 566, 133, 566), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='89 PUBLICATIONS 3,591CITATIONS'),
#  Document(metadata={'page': 0, 'file_name': 'Arita, 1991.pdf', 'region_poly': (136, 504, 223, 504, 223, 520, 136, 520), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='He TArita'),
#  Document(metadata={'page': 0, 'file_name': 'Arita, 1991.pdf', 'region_poly': (144, 584, 218, 584, 218, 600, 144, 600), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='SEE PROFILE'),
#  Document(metadata={'page': 0, 'file_name': 'Arita, 1991.pdf', 'region_poly': (152, 714, 433, 714, 433, 729, 152, 729), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='ecologia y conservacion de carnivoros View'),
#  Document(metadata={'page': 0, 'file_name': 'Arita, 1991.pdf', 'region_poly': (614, 389, 656, 389, 656, 424, 614, 424), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='READS 386'),
#  Document(metadata={'page': 1, 'file_name': 'Arita, 1991.pdf', 'region_poly': (122, 895, 870, 895, 870, 1119, 122, 1119), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='Jones (1965) and Findley (1969) found segregation of certain sympatricspecies of vespertilionid bats along altitudinal gradients in Arizona aud New Mexico. Koopiman (1978) and Graliam (1983 I presented several examples of altitudinal segregation of closely related spccies of the Andes o Peru. Start and Marshall (1976) observed segregation by habitat in two species of Macroglossus tlhat occur sympatrically in Malaysia; M. mininus forages in coastal zones, feeding nainly or the flowers of Sonneratta sp., wbereas M. sobrinus selects lowers of wild banana plants (Musa sp.) that grow inland. Handley (1967) and Bonaccorso (1979) documented several examples of  segregation of sympatric bats by habital and vertical stratum in Ncotropical forests. Some othe examples of segregation of bat specics along gradients of altitude or habitat were discussed by IHumphrey and Bonaccorso (1979).'),
#  Document(metadata={'page': 1, 'file_name': 'Arita, 1991.pdf', 'region_poly': (122, 1127, 871, 1127, 871, 1355, 122, 1355), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='Big (Leptonycteris nioalis) and little (L. curasoae) long-noscd bats are sympatric in central ... and northern Mexico (Arita and Humphrey, 1988). They are simiiar morpliologieally, and the differencc in size is slight; the body-mass ratio L. ntvalis:L. curasoae is L.42:1 (fron means ol 43 L. ntvalis and 13 L. curasoue males from Morelos and Distrito Federal). The existence of (wo speeics in North America was recognized when Davis and Carter (1962) reviewed the genus R The main food of both species is pollen and nectar of the flowers of some tropical and subtropica plants, especially cacti (Cactaceae) and certain species of Agave (Alvarez and Gouzalez-Q., 1970 Gardner, 1977; Quiroz et al., 1986). Baker and Coekrum (1966) suggested geographic and ecologic separation of these Iwo specles in North America, L. nicalis occurring priuarily in the highlands ot eastern Mexico and L. sanbornt (=L. curasoae) occupying lower elevatious in western and'),
#  Document(metadata={'page': 1, 'file_name': 'Arita, 1991.pdf', 'region_poly': (123, 737, 866, 737, 866, 888, 123, 888), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='Based on the competitive-exclusion principle, two specics with identical or sitmilar ecological requirements cannot occur in the satne place at the same time. Wlen two closely related species are sympatric, soveral mcchanistus potentially can differentiate their niches and perinit their distributional ranges to overlap. One such ecological mechanisn is spatial segregation. Species can segregate within a given geographic area according to difflerences in habitat, vertical stratum, or altitude, or by presenting a checkerboard distribution in the case of archipelagoes (Diamond. 1975.1986)'),
#  Document(metadata={'page': 1, 'file_name': 'Arita, 1991.pdf', 'region_poly': (126, 1362, 316, 1362, 316, 1379, 126, 1379), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='J. Mamm, 72(4):706-714.1991'),
#  Document(metadata={'page': 1, 'file_name': 'Arita, 1991.pdf', 'region_poly': (157, 398, 830, 398, 830, 694, 157, 694), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='ABsTuACT.-Analysis of distributional pallerns of bats of tho genus Leptonueteris iu Mexico showed a spatial segregation of the Iwo species. Data on climate and vegetation were galhereo for 43 localities ol L. ntvalis and 269 of L. curasode reported in a recent taxonouic revision o the geus. A statistical analysis using a grid of quadrats of 1" of latitude and longitude showed no segregation of the two species at the ntacrogeographic seale. Ilowever, significant differences were found between the altitude and mean aumual temperature of lxcalities of the (wo species:  L. ntualts occurs in higher and cooler places than I. curasoae. No significant differences exist in terms of mean amuual precipitation; both species occur in drier zones of the couulty. I. nivalis oceurs more frequently in areas with pine (Pinus)-oak (Quercus) and tropical deciduous forests than expected by chance, whcreas L. curasoue is lound mainly in areas with tropieal deciduous and thorn forests. Bats of the genus Leptonycteris are the main pollinators of some suceies of maguey plants (Agave), and the ranges of the bats coincide with that of cettain species of Agave such as A. augustifolta (mezeal plant) A. salnian (pulque plant), and A. tequilang (tequil plant).'),
#  Document(metadata={'page': 1, 'file_name': 'Arita, 1991.pdf', 'region_poly': (180, 305, 806, 305, 806, 345, 180, 345), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='University of Florida, Gainesoille, FL326I1 1'),
#  Document(metadata={'page': 1, 'file_name': 'Arita, 1991.pdf', 'region_poly': (306, 335, 684, 335, 684, 358, 306, 358), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='Present address: Floridu Museunm of Nalural History.'),
#  Document(metadata={'page': 1, 'file_name': 'Arita, 1991.pdf', 'region_poly': (334, 359, 654, 359, 654, 377, 334, 377), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='Universtty of Floridu. Gainesuiile, FL 32011'),
#  Document(metadata={'page': 1, 'file_name': 'Arita, 1991.pdf', 'region_poly': (411, 260, 569, 260, 569, 281, 410, 281), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='HECTOR T. ARITA'),
#  Document(metadata={'page': 1, 'file_name': 'Arita, 1991.pdf', 'region_poly': (871, 42, 1239, 42, 1239, 126, 871, 126), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='Arita, H.T. 1991. Spatial segregation in long-nosed bats, Leptonycteris nivalis and Leptonycteris curasoae, in Mexico. Journa of Mammalogy, 72:706-714.'),
#  Document(metadata={'page': 2, 'file_name': 'Arita, 1991.pdf', 'region_poly': (104, 570, 860, 570, 860, 670, 104, 670), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='To test the hypotlhesis of geographic segregation of long-nosed lbats, Mexico was divided into 218 quadrats of one degree of latitude and lougitude. All localities of Leptonycteris in Mexico reported by Atita and llumphrey (1988) were located on a map and assigned to their respective quadrat. A two-by-lwo contingenev table analysis was enployed to test the null hypothesis that the distributions of l. ntoalts and L. curasoae in Mexico are independent'),
#  Document(metadata={'page': 2, 'file_name': 'Arita, 1991.pdf', 'region_poly': (106, 244, 856, 244, 856, 384, 106, 384), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='species ol maguey plants (Agave). Bats of the genus Leptonycteris are known to be the primary pollinators of magueyes (Eguiarte and Burquez, 1987; Howell, 1979, Howell and Hartl, 1980: Howell and Botl, 1981; Martinez del Rio and Eguiarte, 1987). If a close association exists betweeo these plants and bats, matching distributional ranges are to be expected for both groups ol organisms. Furthermore, if spatial segregation occurs between the Iwo species of Leptonucters. ann association ol each species of lat with a partieular speeies of Agooe inight be predicted'),
#  Document(metadata={'page': 2, 'file_name': 'Arita, 1991.pdf', 'region_poly': (107, 141, 851, 141, 851, 217, 107, 217), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content="central Mexico. Since then, many localities have been added to the kuown distribution of Lep tonycteris in Mexico, allowing more rigorous analysis of Baker and Cockrun's (1966) idea. The objective of this paper is to use availablc informalion to test the hypothesis thiat spalial segregalion"),
#  Document(metadata={'page': 2, 'file_name': 'Arita, 1991.pdf', 'region_poly': (107, 676, 860, 676, 860, 820, 107, 820), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='For each locality, I compiled metcorological data (ron Gareia (1981). These data included geographj coordinates, altitude, mcan annual precipitation, and mean annual temperature. Must of te stalions had records for both temperature and precipitation for ≥10 years of observations, but a lew lacked information tor one of these variables. ! first performed a Shapiro-Wilk test for uonmality to,analyze the frequeney distribution of altitude. temperalure., and precipitation of thc localities of botl species. All dlistributions were s significantly different from a nornal distribution (P <0.01), and I used only nonparametric tests in subsequent comparisons.'),
#  Document(metadata={'page': 2, 'file_name': 'Arita, 1991.pdf', 'region_poly': (109, 825, 861, 825, 861, 1029, 109, 1029), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='Lotng-nosed bats are considered migratory specics (Alvarez and Gonzalez-(), 1970;Easterla, 1973;Hayward and Cookrum, 1971; Quiroz el al., I986), su sensonal novements in altitude or latitudle of one or buth species eouldl obscure dilferences between the specics. To analyze the extent of migration, I divided localities of each species into dry-season localities (records from Novemher to May) and wet-season localities (records froin June to October). Al(lhough this division could he considered arbitrary, It corresponds with the ap. proxitnale dation of the two main scasons in nmosi places in Mexico (Garcia, 1981). Wilcoxon (wo-sanple tests were perlorrned to compare for each species the localities of the two seasons int terms of altitude, mean atuual temperature, and moan annual precipitation. Subsequontly, I used additional Wilcoxon bwo-snmple tests comparing the localities of both species to test the hypothesis that differcnces in any of the three variables indicated spatial segregation of the two bat species'),
#  Document(metadata={'page': 2, 'file_name': 'Arita, 1991.pdf', 'region_poly': (110, 448, 857, 448, 857, 570, 110, 570), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='Rcview of the literature pertaining to the listribution of te geus Leptonncteris las been hindered b monenclatural probleus. In a recent taxonotnic review of the genus, Arita and IIunphrey (1988) reported that many museutn spccimens labeled as L. nioalis were nisidentilied, and that tbis spocies has a moro restricted distribution than formerly bclieved. To avoid problems with crroneous distribulional records. I relicd only on localities reported by Arita and Humplrey (1988), who examined specimens ol L. ninalis froin 43 localities and of L. curasode from 269 localities (Fig. 1).'),
#  Document(metadata={'page': 2, 'file_name': 'Arita, 1991.pdf', 'region_poly': (110, 1034, 862, 1034, 862, 1239, 110, 1239), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content="I also compared the distributional range of the two bat species in terins of vegetation. I mapped localities of Leptonycteris on Rzedowski's (1978) vegetation map and tallied the number of localities of each species of bat in each of thc eight major types of vegetation: tropical rain forest; semi-evergreen tropical forest: tropical deciduous forest; thorn forest; grassland or savanna; desert or chapatral;pine (finus)-oak(Ouercus) Iorest; and cloud forest. I compared the frequency of oach bat species in each vegetation type with a pull distribution based on the proportion of Mexican territory covered by each of the eight types of vegetation e elg Deviation fron the null distribution woukd sugges! a nonrandon distribution of Leptonucterks species in terms of vegetation types, deuonstrating a seloction of some of tlie available environuents. I also used a binomial tost to compare the observed mumber of localities with the number of loealities expected to fail f a given type of vegetation if the distributions were randorn."),
#  Document(metadata={'page': 2, 'file_name': 'Arita, 1991.pdf', 'region_poly': (112, 1245, 863, 1245, 863, 1340, 112, 1340), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='Distributional data presrnted by Gentry (1982) for Agace spccies were used to compare the distributions ol tlhese agaves in Mexico with distributions of both species of long-nosed bats, looking for a geoguaphic association supporting the hypothesis of an ecological relationship between the plants and one or both of the bat species. Special emphasis was given to three magueyes that are sources of traditional beverages in Mexico: Agave angustifolia, mezcal plant, A. salntlana, pulque plant, and A. tequilang. teqoila plant. I tested the'),
#  Document(metadata={'page': 3, 'file_name': 'Arita, 1991.pdf', 'region_poly': (161, 147, 917, 147, 917, 223, 161, 223), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='hypothesis of an ossociation bctween L. curasoae and A. angustifolia by using a binonial distribution elassilying localities of bats as insilc or outsile the range of the agave. I made a qualitalive conparison of the distributions of L. ntorlis and A. sulnuiang, but no quantitalive test coull be performerl hecause of tho small sample.'),
#  Document(metadata={'page': 3, 'file_name': 'Arita, 1991.pdf', 'region_poly': (163, 276, 917, 276, 917, 361, 163, 361), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='Of thc 218 1° quadrats that inelude Mexican territory, 24 include localities of L. ntvolis and 78 include L. curasoae. Sixtecn quadrats inciude localities of botb species. A. two-by-iwo con- tingency-table analysis demonstrated a significant positive association between the two species of bats on a macrogeographic seale (x’ = 11.2, d.f. = 1, P < 0.001, Fig. 1).'),
#  Document(metadata={'page': 3, 'file_name': 'Arita, 1991.pdf', 'region_poly': (166, 367, 917, 367, 917, 500, 166, 500), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='For L. nivalis, I found no significant seasonal variation in altitude (Wilcoxon two-samplo test. P = (.56), mean annual temperature (P = 0.78), or mean annual precipitation(P=0.16). Similar results were obtained for L. curasoae (F = 0.17 for altitude, P= 0.41 for temperature, and P =0.32 precipitation). These results indicate that no seasonal pattern can be detected at the macrogcographic level. Because tno seasoual variation can be shown, I combined data for each species without regard to tiine of year.'),
#  Document(metadata={'page': 3, 'file_name': 'Arita, 1991.pdf', 'region_poly': (166, 503, 917, 503, 917, 683, 166, 683), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='Most localities at which L. nioalis has been collected are between 1,000 and 2.200 in elevation (Fig. 2a), but L. nitalfs can reach highcr elevations; Saussure (1860) described the typo locality of this species at the snow line on the Pico de Orizaba, and Koestner (1941) reported a colony ol L. nipalis in the Cerro Fotosi, Nuevo Leon, at 3,780 m. In contrast,L. curdsoae, oceurs al lower elevations (Fig. 2a). Most locality records for this species are <1,800 n, and approximately one-third of them are <300 m. Unlike L. nivalis, L. curasoae frequently is caught at sea level. The altitude of the localities of L. nivalts is significantly higher than that of L. curasode (Wilcoxon lwo-sample test, P <0.001)'),
#  Document(metadata={'page': 3, 'file_name': 'Arita, 1991.pdf', 'region_poly': (166, 691, 918, 691, 918, 821, 166, 821), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='Correlated with differences in altitude, a significant difference in mean annual temperalure exists between localities of the two species (Fig. 2b). The node of the frequency distribution of focalities of L. nivalis is 20C, whereas that for localities of L. curasoae is 25C. There is no significant difference in amnual rainfall between localities of the two species of loug-nosed bats (Fig. 2c). The frequency distributions of both specics are almost the same, with a tmode at about 750 mm.'),
#  Document(metadata={'page': 3, 'file_name': 'Arita, 1991.pdf', 'region_poly': (167, 825, 917, 825, 917, 1027, 167, 1027), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='Localities of L. nivalis show a tonrandom distribution among tvpes of vegetation (x  = 100.1. md d.f. = 7, P < 0.001, Fig. 3). Only four of the cight types of vegetation are represented among known localities of L. nivalts. The big long-nosed bat is positively associated with tropical deciduous and pine-oak forests (binomial tests, P <0.01 and P < 0.001, respectively), and negatively associated with grassland (P < 0.01) and tropica! rain forests (P <0.05). Similarly. the distribution of L. curasode among types of vegetation is not random (x’ = 624.7, d.f. = 7. P < 0.001, Fig. 3). The little long-nosed bat occurs more frequently in dry forests (tropical deciduous, thorn, and semi-evergreen) than expected by chance (P < 0.001) and is negatively associated with deserts, grasslands, and tropical rain forests (P < 0.001)'),
#  Document(metadata={'page': 3, 'file_name': 'Arita, 1991.pdf', 'region_poly': (171, 1032, 921, 1032, 921, 1306, 171, 1306), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='The distribution of L. cutdsoae in Mexico coincides with the range of the mezcal plant. A in ocalities   ant  Ih Th   curasoae ie ran concentrated mainly on the Baja California peninsula and in northeastern Mexico. Also, some populations ol A. angustifolia occur in the northern part of the Yucatan peninsula where the little long-nosed bat does not occur. A. angustifolta is mainly a form of the Moxican tropical lowlands, occurring chielly in tropical savannas, thorn forests, and tropical deciduous forests, in plo areas with anmual precipitation from 250 to 1,680 mm. Distributional records are from sea level to ca. 1,500 m (Centry, 1982). The tequila plant (A. tequilano) is closely related to A. angustifolta and nay only be a variety of the mczcal plant (Centry, 1982). This plant grows wild in the vicinity ol Tequila, Jalisco, where the little long-nosed bat has becn collected (Arita and Hum plrev, 1988).'),
#  Document(metadata={'page': 3, 'file_name': 'Arita, 1991.pdf', 'region_poly': (193, 1312, 922, 1312, 922, 1331, 193, 1331), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='The pulque plant (A. salmtana) and other species of the Salmianae group, as arranged by'),
#  Document(metadata={'page': 6, 'file_name': 'Arita, 1991.pdf', 'region_poly': (413, 1128, 1169, 1128, 1169, 1192, 413, 1192), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='Gentry (1982), grow in habitats where I. nionlis is abudant. These plants are native to the lighlands of the Transverse Volcanic Belt aud are found at elevations between 1.250 aud 2.500 m, where annual rainfall ranges from 350 to 1,000 mm (Gentry, 1982).'),
#  Document(metadata={'page': 6, 'file_name': 'Arita, 1991.pdf', 'region_poly': (414, 1247, 1169, 1247, 1169, 1484, 414, 1484), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='Long-nosed bats are not geographically segregated. A[ter Davis and Carter (1962) demo- strated the prescnce of two spccies of Leptonycteris in North America, it was believed that they were syimpatric only in central Mexico. Most locality records reported by Baker and Coekrun (1966), Ramirez-P. and Alvarez (1972), and IHall (1981) showed that L. ntoalis was fouud mainly in northeastern Mexico, whereas L. curasode occurred chiefly in western and southern Mexico. However, the revision by Arita and IIumphrey (1988) demonstrated thal L. curasoue is more widespread in northeastern Mexico than formerly bclieved (Wilson el al., 1985). and that the idea of a geographic segregation between long-nosed bats was cuused by misidentification of many specimens of L. curasoae as L. nipalis. In rcality, the distributional range of L. nitalis i almost completely included in the range of I. curasoae. The only placus outside the rangc of L. curasoae where L. ntvalis is known to oceur are the Big Bend National Park arca iu Texas'),
#  Document(metadata={'page': 7, 'file_name': 'Arita, 1991.pdf', 'region_poly': (168, 141, 920, 141, 920, 202, 168, 202), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='(Easterla, 1973) and sotne tparts of Coaloila (Easterla, 1972; Wilson et al., 1985). My analysis contirins a positive association bctween the two Leptonycteris species at the macrogeographio scale'),
#  Document(metadata={'page': 7, 'file_name': 'Arita, 1991.pdf', 'region_poly': (169, 204, 920, 204, 920, 430, 169, 430), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='As suggested by Baker and Cockrum (1966), long-nosed bats segregate in an altitudinal gradient, with L. nioalts oecurring at higher and cooler localities than L. curasoue (Fig. 2). Both species are found more frequently in dry areas of the country, with annual rainfall <2,000 mn. Mexico generally is a dry country, althougl it includes regions with anmual precipitation of >4,000 mtn. Long-nosed bats do not occur in those parts of the country (Fig. 2), suggesting that bats of the genus Leptonycteris are adapted to arid conditions, as diseussed by Koopman (1981). The two species of long-nosed bat occur at localities with different types of vegetation (IFig. 3). As obscrved by Baker and Cockrum (1966), the nost comnon habitat for L. nivalis is the transition zone between tropieal deciduous forest and pine-oak forest. Couversely. L.curasoae is more frequently found in places characterized by tropical aud subtropical dry forests.'),
#  Document(metadata={'page': 7, 'file_name': 'Arita, 1991.pdf', 'region_poly': (172, 439, 923, 439, 923, 709, 172, 709), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='The mezcal plant and L. curasoae occur in almost identical areas; uany of the localities of A. angustifolia listed by Gentry (1982) are close to collection sitos of the little long-nosed bat. This geographic association, and the close plant-pollinator relatiouship demonstrated belween L. curasoae and other species of Agavaceae (Eguiarte and Burquez, 1987; Howell, 1979; Howel and fHartl, 1980, Ilowell and Roth, 1981) might suggest that L. curdsoae coukl be a pollinator of wild mezcal plants. However, the possibility exists that the posilive gcographic association .. demonstrated herein may be only a consequence of both the bat and the agave occurring cbielly in arid parts of the country; only direct field observations could confirm an ecological association between these species. A. salmiana is a bat-pollinated plant (Martinez del Rio and Eguiarte 1987), but thc identity of tho species that pollinates this maguey remains unknown. On the basis of the habitats in which the plant grows, that pollinator could be L. nioalis, but this must be confirmed by field studies.'),
#  Document(metadata={'page': 7, 'file_name': 'Arita, 1991.pdf', 'region_poly': (174, 714, 929, 714, 929, 891, 174, 891), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='The two species of long-nosed bats seern to have similar fceding lhabits and fotaging strategies Alvarez and Gonzalez-(). (1970) fouud that both specics of Leptonycteris depend beavily on plauts of the genera Agave, Myrtillocactus, Cetba, Ipomoea, and Bombux, and that the only dietary difference between the two species was the relative proportion of pollen of these plant in their diet. Given the altitudinal segregation of long-osed bats, it is possible that even if the lwo species of Leptonycteris feed on nectar and pollen of the same genera of plants, as dem onstrated by Alvarez and Gonzalez-Q. (1970), they could specialize on different species; it seems that L. curasode exploits lowland species of magueyes and L. nipalis leods on highland species'),
#  Document(metadata={'page': 7, 'file_name': 'Arita, 1991.pdf', 'region_poly': (180, 895, 929, 895, 929, 1149, 180, 1149), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='Diamond (1986) found spatial segregation to be the most froquent mechanism allowing pairs of bird species to cxist sympatrically in New Guinea; among sucl pairs of species, be found little evidence of ecological segregation in feeding habits or body mass. Diamond (1986) found that pairs of bird species in New Guinea willi body-mass ratios <1.7:l are never truly syntopic, unless they have different diets or foraging behavior. Morplological and dietary similarities between the two species of Leptumycteris suggest that altitudinal segregation is the mechanisn that allows them to be sympatric. This segrcgation, liowever, is incomplete; there is overlap in altitudes occupied by the two species (Fig. 2), and there are several reports of both species being caught in the same place at the same timc (Villa-R., 1967; Wilson et al., 1985). Currently, no information is available to suggest an ecological mechanism that could explain these cascs of syntopic oc currence of long-nosed bats'),
#  Document(metadata={'page': 7, 'file_name': 'Arita, 1991.pdf', 'region_poly': (185, 1199, 933, 1199, 933, 1332, 185, 1332), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='La existencia de una segregacion espacial entre las dos especics de murcielagos magueyeros (genero Leptonycteris) puede ser denostrada mediante el analisis de los patrones de distribucion de estos auimales. Se obtuvieron datos sobre el clina y la vegetacion de 43 localidades de L. nivalts y 269 de L. curasoae en Mexico usatdo como base los registros de una revision taxonomica del genero recientemente publicada. El analisis estadistico de la distribucion de las especies utilizando cuadrantes de un grado por lado no pudo denostrar una scgregacion de las especies'),
#  Document(metadata={'page': 8, 'file_name': 'Arita, 1991.pdf', 'region_poly': (100, 78, 215, 78, 215, 96, 100, 96), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='November 1991'),
#  Document(metadata={'page': 8, 'file_name': 'Arita, 1991.pdf', 'region_poly': (102, 769, 467, 769, 467, 836, 102, 836), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='BAKER, R. I, AND E. L. COCKRUM. 1966. Geograph ical and ecological range of the long-nosed bats. Leptonycteris. journal of Mamnalogy, 47:329- 331'),
#  Document(metadata={'page': 8, 'file_name': 'Arita, 1991.pdf', 'region_poly': (103, 437, 858, 437, 858, 538, 103, 538), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='I thank S. R. Ilunphrey for continuous suppott of my research on long-osed bats. C. Martinez del Rio D. E. Wilson, and an anonynous reviewer provided good ideas aud stimulhting criticisnt. This rcseareh was made possible by scholarships fron the Cousejo Nacional de Ciencia y Tocnologia and the Universidad Nacional de Mexico. This is a contribution of the Progran for Studies iu Tropieal Conservation and a contribution of the Journal Series, Florida Agricultural Exueriueut Station. Gainesville Florid'),
#  Document(metadata={'page': 8, 'file_name': 'Arita, 1991.pdf', 'region_poly': (104, 141, 855, 141, 855, 386, 104, 386), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='crop cu. cias alya..se enconimfon dnetenctas aguneateu eratura media oeci L.1 zonas mas allas y frias que L. curasode. No se encontraron diferencias entre la precipitacion media atual de las localidades de las dos especies; ambas oxeupan lus partes mas secas del pais. a L. nivalis se encuentra en areas con bosque de encino y coniferas o con bosque tropical cadueifolic con nayor frecuencia que la esperadla al azar, mientras que L. curasode se encuentra princi- palmente en los bosques tropical caducifolio y cspinoso. Los inurcielagos del genero L.eptonycteris son los ptincipales polinizadores de algunos nagueyes (genero Agave), v sus patrones de distri- bucion coincilen con lus de algunas especies de magueyes de importaneia comercial, cono el maguey mezcalero (A. angustifolta), el maguey pulquero (A. salmiana) y el maguey tequilerc (A. tequilana)'),
#  Document(metadata={'page': 8, 'file_name': 'Arita, 1991.pdf', 'region_poly': (104, 687, 467, 687, 467, 762, 104, 762), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='ARITA, IH. T., AND S.R.HUMPHREY. 1988. Revision taxonomica de los mureielagos inagueyeros del ge nero Leptongcterts (Chiroplera: Phyllostomidae). Aeta Zoologica Mexicana, nueva serie. 29:1-60.'),
#  Document(metadata={'page': 8, 'file_name': 'Arita, 1991.pdf', 'region_poly': (105, 597, 464, 597, 464, 679, 105, 679), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='ALVAREZ, T., AND L. GONZALEZ-(). 1970. Analisis polinico del contenido gastrico de murcielagos Glossophaginae de Mexico. Anales de la Eseuela Nacional de Ciencias Biologicas (Mexico), 18:137- 165.'),
#  Document(metadata={'page': 8, 'file_name': 'Arita, 1991.pdf', 'region_poly': (105, 987, 473, 987, 473, 1084, 105, 1084), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='DIAMOND, J. M. 1975. Assenmbly of species con- munities. Pp. 342-444, tn Ecology and evolution of cominunities (M. L. Cody and I. M. Diamond. eds.). Belknap Press, Cambridge, Massachuselts. 545 pp.'),
#  Document(metadata={'page': 8, 'file_name': 'Arita, 1991.pdf', 'region_poly': (108, 841, 466, 841, 466, 910, 108, 910), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='BONACCORSO, F.J. 1979. Foraging and reprodue tive ecology in a Panaanian bat cominunily. Bul letin of the Florida State Museum, Biological Sei- ences, 24:350-408 y'),
# ...
#  Document(metadata={'page': 8, 'file_name': 'Arita, 1991.pdf', 'region_poly': (489, 1316, 859, 1316, 859, 1336, 489, 1336), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='IloWELL, D. J., AND B. S. ROTH. 1981. Sexual re'),
#  Document(metadata={'page': 8, 'file_name': 'Arita, 1991.pdf', 'region_poly': (492, 1068, 860, 1068, 860, 1123, 492, 1123), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='HANDLEY, C. O., JR. 1967. Bals of the canopy of an Amazotian forest. Atlas Simposio Biota Ama zonica,5:211-215.'),
#  Document(metadata={'page': 8, 'file_name': 'Arita, 1991.pdf', 'region_poly': (493, 903, 859, 903, 859, 952, 493, 952), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content="GENTRY, I1.S. 1982. Agaves of contineutal North America. Univetsily of Arizona I'ress, Tueson, 670 pp."),
#  Document(metadata={'page': 8, 'file_name': 'Arita, 1991.pdf', 'region_poly': (493, 1261, 859, 1261, 859, 1314, 493, 1314), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='lloWELL, ). J, AND D. L. HARTI. 1980. Optitna loraging in glossophagine bats: when to give up. The Ainerican Naluralist. 115:696-704.'),
#  Document(metadata={'page': 8, 'file_name': 'Arita, 1991.pdf', 'region_poly': (494, 957, 858, 957, 858, 1011, 494, 1011), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='GAA11AM, G. I 1983. Changes in bat species di versity along an elevational gradient up the Pe ruvian Andes. Journal of Maminalogy. 64:559-571.'),
#  Document(metadata={'page': 8, 'file_name': 'Arita, 1991.pdf', 'region_poly': (494, 1199, 860, 1199, 860, 1258, 494, 1258), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='HOWELL, D. J. 1979. Flock foraging in tectar-eal iug bats: advantages to the bals and to the host plant. The American Naturalist, 114:23-49'),
#  Document(metadata={'page': 8, 'file_name': 'Arita, 1991.pdf', 'region_poly': (495, 1012, 857, 1012, 857, 1069, 495, 1069), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='IIALL,E.R. 1981. The mamumals of North America Second ed. Joln Wiley and Sons. New York. |:1- G00+90'),
#  Document(metadata={'page': 8, 'file_name': 'Arita, 1991.pdf', 'region_poly': (495, 1127, 856, 1127, 856, 1198, 495, 1198), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='HAYWARD. B. J, AND E. L. CoCKRtM. 1971. The nalural history of the western loug-nosed bat Lep tonycteris sanborni. Weslern New Mexico Uni versity Research in Science, 1:75-123.'),
#  Document(metadata={'page': 8, 'file_name': 'Arita, 1991.pdf', 'region_poly': (503, 597, 854, 597, 854, 632, 503, 632), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='rous species of Agavaccae. Tle Southwestern Nat- uralist, 32:169--178'),
#  Document(metadata={'page': 9, 'file_name': 'Arita, 1991.pdf', 'region_poly': (161, 297, 528, 297, 528, 365, 161, 365), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='JONES,C. 1965. Eeologicaldistributionsand activity periods of bats of the Mogollon Mounitains area o New Mexieo and adjacent Arizona. Tulane Studie! in Zoology, 12:93-100.'),
#  Document(metadata={'page': 9, 'file_name': 'Arita, 1991.pdf', 'region_poly': (162, 188, 524, 188, 524, 295, 162, 295), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='Population and comununity eeology. Pp.409-441. tn Biology of bats of the New World family Phvl- lostomalidae. Pait 111 (R. J. Baker, J. K. Jones, Jr., and D. C. Carter, eds.). Spectal Publieations, The Museum, Texas Teeh University, 16:1-441.'),
#  Document(metadata={'page': 9, 'file_name': 'Arita, 1991.pdf', 'region_poly': (166, 371, 528, 371, 528, 423, 166, 423), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='KOESTNER, E. I. 1941. An annotaled list of main tmals eollected in Nuevo Lcon, Mexico, in 1938 as The Great Basin Naturalist. 2:9-15.'),
#  Document(metadata={'page': 9, 'file_name': 'Arita, 1991.pdf', 'region_poly': (166, 430, 529, 430, 529, 482, 166, 482), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='KOOTMAN, K. F. 1978.Zoogeography of Peruvian bats with special emphasis on the role of the Andes. Ainerican Museum Novitales, 2651:1-83'),
#  Document(metadata={'page': 9, 'file_name': 'Arita, 1991.pdf', 'region_poly': (170, 541, 533, 541, 533, 616, 170, 616), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='MARTINEZ DEL Rio, C., AND L. F. EGUIANTE 1987 Bird visitatiou lo Agave salmiana: conparisons anong hummingbirds and perching birds. The Condor, 89:357-363.'),
#  Document(metadata={'page': 9, 'file_name': 'Arita, 1991.pdf', 'region_poly': (170, 616, 529, 616, 529, 655, 170, 655), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='Quntoz, D. L., M. S. XELIIUANTZI,AND M. C. ZAMORA. 1986. Analisis palinologico del coutenido gastro'),
#  Document(metadata={'page': 9, 'file_name': 'Arita, 1991.pdf', 'region_poly': (171, 485, 529, 485, 529, 542, 171, 542), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='1981. The distributional patterns of New World nectar-feeding bats. Annals of the Missouri Botanical Garden, 68:352-369.'),
#  Document(metadata={'page': 9, 'file_name': 'Arita, 1991.pdf', 'region_poly': (183, 144, 522, 144, 522, 181, 183, 181), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='production in agaves: the benefits of bats; the cost of semelparous advertising. Ecology, 62:1-7 7'),
#  Document(metadata={'page': 9, 'file_name': 'Arita, 1991.pdf', 'region_poly': (185, 669, 594, 669, 594, 685, 185, 685), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='Submitted 20 October 1968. Accepted 3 Lecember 1990.'),
#  Document(metadata={'page': 9, 'file_name': 'Arita, 1991.pdf', 'region_poly': (547, 313, 917, 313, 917, 348, 547, 348), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='RZEDOW5KI, J. 1978. Vegetacion de Mexico. Li musa, Mexico City, 432 pp.'),
#  Document(metadata={'page': 9, 'file_name': 'Arita, 1991.pdf', 'region_poly': (548, 229, 913, 229, 913, 309, 548, 309), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='los imurcielagos del genero Leptonycteris en Mexi eo, con la desiguaciou del lectolipo de L. gerba- buenae Martinez y Villa, 1940. The Southwestern Naturalist, 16:249-259'),
#  Document(metadata={'page': 9, 'file_name': 'Arita, 1991.pdf', 'region_poly': (549, 345, 916, 345, 916, 399, 549, 399), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='SAUSSURE,M. 1860. Note sur quelques mammiferes du Mexique. Revile et Magazinede Zoologie,Iaris, series 2, 12:281-293.'),
#  Document(metadata={'page': 9, 'file_name': 'Arita, 1991.pdf', 'region_poly': (550, 403, 918, 403, 918, 503, 550, 503), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='START, A. N., AND A. G. MARSHALL. 1976. Neclar- ivorous bats as pollinators of trees in West Malay- sia. Pp 141-150, in Tropical trees. Variation, breeding and conscrvation (l. Burlev and B. T. Styles, eds.). Academic Press, London, 243 pp'),
#  Document(metadata={'page': 9, 'file_name': 'Arita, 1991.pdf', 'region_poly': (554, 560, 920, 560, 920, 631, 554, 631), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='WILSON, D. E., R. A. MEDELLIN, D. V. LANNING, AND 1H.T. ARITA. 1985. Los murcielagos del ioreste de Mexico. con utia lista de especies. Acta Zoolo gica Mexicaina, nueva serie, 8:1-26'),
#  Document(metadata={'page': 9, 'file_name': 'Arita, 1991.pdf', 'region_poly': (555, 505, 916, 505, 916, 558, 555, 558), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='VHLA-R., B. 1967. Los mureielagos de Mexico. In- e slituto de Biologia, Universidad Nacional Aulono- ma de Mexico, 491 pp.'),
#  Document(metadata={'page': 9, 'file_name': 'Arita, 1991.pdf', 'region_poly': (561, 144, 909, 144, 909, 216, 561, 216), 'input_file': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'), 'species_folder': 'test species_A', 'output_folder': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output', 'output_file': '/home/camilo/Documents/00-Conabio/by_species/test species_A/output/Arita, 1991.json'}, page_content='intestinal de los murcielagos Clossophaga soricina y Leptonycteris verbabuenae de las grutas de jux tlahuaca, Guerrero. Instituto Nacional de Autro pologia e lIistoria, Mexico City, 51 pp.')]

# %%
path_dic
# Out:
# {'file_input_path': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'),
#  'folder_output_path': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/output'),
#  'species_folder': 'test species_A',
#  'file_name': 'Arita, 1991.pdf'}

# %%
file_path_dict
# Out:
# {'file_input_path': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/test species_A_bibliografía/Arita, 1991.pdf'),
#  'folder_output_path': PosixPath('/home/camilo/Documents/00-Conabio/by_species/test species_A/output'),
#  'species_folder': 'test species_A',
#  'file_name': 'Arita, 1991.pdf'}

# %%
for res, path_dic in  zip(dfs,list_paths):
    print(df_to_doc(res, path_dic)[0].file_name )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[88], line 2
#       1 for res, path_dic in  zip(dfs,list_paths):
# ----> 2     print(df_to_doc(res, path_dic)[0].file_name )
#
# AttributeError: 'Document' object has no attribute 'file_name'

# %%
text = lang_dumps(df_to_doc(res, path_dic))
eval(text)[0].get('kwargs')["page_content"]
# Out:
# 'Some of the authors ofthis publication are also working on these related projects:'
